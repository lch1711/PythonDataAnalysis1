# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 실습 데이터셋 안내
#
# - 2022년 1~12월 간 lg.com의 마케팅 실적 데이터입니다.<br><br>
# - 변수(열)에 대한 간단한 설명입니다.
#
# | 열이름 | 설명 | 특징 |
# | :----- | :--- | :--- |
# | country | 국가 코드 | au: 호주, br: 브라질, de: 독일, fr: 프랑스, it: 이탈리아, <br> uk: 영국 |
# | date | 웹 행동 발생 일자 | 2022.01.01~2022.12.31 |
# | product_category | 제품 대분류 | HE, HA, BS(LG전자 사업부별 분류) |
# | product_subcategory | 제품 소분류 | 13개 카테고리(제품별 분류) |
# | product_detail_page | 제품 상세 페이지 유입 수 | 수치형 |
# | add_to_cart | 장바구니 추가 클릭 수 | 수치형 |
# | sales_amt | 판매대수 | 수치형(대) |
# | sales_usd | 판매금액 | 수치형(USD) |
#
# - 실습 데이터인 csv 파일은 data 폴더에 있습니다.
#   - 구분자는 콤마(,)이고 인코딩 방식은 **ASCII**입니다.

# %% [markdown]
# ### 관련 라이브러리 호출

# %%
# 관련 라이브러리를 호출합니다.
import os
import chardet
import numpy as np
import pandas as pd
import joblib

# %%
# Jupyter Notebook에서 실수를 소수점 셋째 자리까지 출력하도록 설정합니다.
# %precision 3
# Out:
# '%.3f'

# %%
# pandas 객체에서 실수를 소수점 셋째 자리까지 출력하도록 설정합니다.
pd.options.display.precision = 3

# %% [markdown]
# ### 작업 경로 확인 및 변경

# %%
# 현재 작업 경로를 확인합니다.
os.getcwd()
# Out:
# 'C:\\Users\\hdsce\\Documents\\PythonDataAnalysis1\\project'

# %%
# data 폴더로 작업 경로를 변경합니다.
os.chdir('../data')

# %%
# 작업 경로에 있는 폴더명과 파일명을 출력합니다.
os.listdir()
# Out:
# ['APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged_Seoul_2022.txt',
#  'APT_Merged_Seoul_2022.xlsx',
#  'APT_Merged_Seoul_2022.z',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'APT_Price_Seoul_2020_2022.z',
#  'Frequency.xlsx',
#  'NA_Sample.xlsx',
#  'online_mall.csv']

# %% [markdown]
# ### 인코딩 방식 확인

# %%
# csv 파일명을 변수에 할당합니다. 여러 번 재사용하기 위함입니다.
fileName = 'online_mall.csv'

# %%
# csv 파일을 bytes 문자열로 읽고 text에 할당합니다.
# [힌트] open(), read() 함수를 사용하세요.
text = open(file = fileName, mode = 'rb').read()

# %%
text[:100]
# Out:
# b',country,date,product_category,product_subcategory,product_detail_page,add_to_cart,sales_amt,sales_u'

# %%
# 바이너리 텍스트의 인코딩 방식을 확인합니다.
# [힌트] chardet.detect() 함수를 사용하세요.
chardet.detect(text)
# Out:
# {'encoding': 'ascii', 'confidence': 1.000, 'language': ''}

# %% [markdown]
# ### 실습 데이터셋 준비

# %%
# csv 파일을 읽고 데이터프레임 rawdat를 생성합니다.
# [힌트] pd.read_csv() 함수를 사용하세요.
# [참고] EUC-KR은 CP949의 부분집합입니다.
rawdat = pd.read_csv(fileName)

# %%
# rawdat의 정보를 확인합니다.
# [힌트] info() 함수를 사용하세요.
rawdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13908 entries, 0 to 13907
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           13908 non-null  int64
#  1   country              13908 non-null  object
#  2   date                 13908 non-null  int64
#  3   product_category     13908 non-null  object
#  4   product_subcategory  13908 non-null  object
#  5   product_detail_page  13908 non-null  int64
#  6   add_to_cart          13908 non-null  int64
#  7   sales_amt            13908 non-null  int64
#  8   sales_usd            13908 non-null  float64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 978.0+ KB

# %%
# rawdat의 처음 5행을 출력합니다.
# [힌트] head() 함수를 사용하세요.
rawdat.head()
# Out:
#    Unnamed: 0 country      date product_category product_subcategory  \
# 0           0      au  20220101               HE                  TV
# 1           1      au  20220102               HA        Refrigerator
# 2           2      au  20220102               HE                  TV
# 3           3      au  20220103               HA   Cooking_Appliance
# 4           4      au  20220103               HA        Refrigerator
#
#    product_detail_page  add_to_cart  sales_amt  sales_usd
# 0                 4485           17         10     398.96
# 1                 3419           20          2    1212.33
# 2                 4676           14          3     113.99
# 3                  546            3          2     279.17
# 4                 3691            7          5     106.26

# %%
# rawdat의 마지막 5행을 출력합니다.
# [힌트] tail() 함수를 사용하세요.
rawdat.tail()
# Out:
#        Unnamed: 0 country      date product_category product_subcategory  \
# 13903       13903      uk  20221231               HA        Refrigerator
# 13904       13904      uk  20221231               HA              Washer
# 13905       13905      uk  20221231               HA        Washer_Dryer
# 13906       13906      uk  20221231               HE           Audio_CAV
# 13907       13907      uk  20221231               HE                  TV
#
#        product_detail_page  add_to_cart  sales_amt  sales_usd
# 13903                  756           13          6   12919.57
# 13904                  579           21          7    6977.92
# 13905                  278           10          4    3722.52
# 13906                 1939           32         11     496.18
# 13907                 8393          157          7   10802.75

# %% [markdown]
# ### 실습 데이터셋 전처리

# %%
rawdat.columns
# Out:
# Index(['Unnamed: 0', 'country', 'date', 'product_category',
#        'product_subcategory', 'product_detail_page', 'add_to_cart',
#        'sales_amt', 'sales_usd'],
#       dtype='object')

# %%
# 불필요한 열을 삭제합니다.
# [힌트] drop() 함수를 실행한 결과를 데이터프레임에 재할당해야 합니다.
rawdat = rawdat.drop(columns = ['Unnamed: 0'])

# %%
# rawdat의 처음 5행을 출력합니다.
rawdat.head()
# Out:
#   country      date product_category product_subcategory  product_detail_page  \
# 0      au  20220101               HE                  TV                 4485
# 1      au  20220102               HA        Refrigerator                 3419
# 2      au  20220102               HE                  TV                 4676
# 3      au  20220103               HA   Cooking_Appliance                  546
# 4      au  20220103               HA        Refrigerator                 3691
#
#    add_to_cart  sales_amt  sales_usd
# 0           17         10     398.96
# 1           20          2    1212.33
# 2           14          3     113.99
# 3            3          2     279.17
# 4            7          5     106.26

# %%
# rawdat의 열이름을 출력합니다.
rawdat.columns
# Out:
# Index(['country', 'date', 'product_category', 'product_subcategory',
#        'product_detail_page', 'add_to_cart', 'sales_amt', 'sales_usd'],
#       dtype='object')

# %%
# rawdat의 열이름에서 'product_'를 삭제한 결과를 출력합니다.
rawdat.columns.str.replace(pat = 'product_', repl = '')
# Out:
# Index(['country', 'date', 'category', 'subcategory', 'detail_page',
#        'add_to_cart', 'sales_amt', 'sales_usd'],
#       dtype='object')

# %%
# 위 코드 실행 결과를 rawdat 열이름에 할당하여 변경합니다.
rawdat.columns = rawdat.columns.str.replace(pat = 'product_', repl = '')

# %%
# rawdat의 처음 5행을 출력합니다.
rawdat.head()
# Out:
#   country      date category        subcategory  detail_page  add_to_cart  \
# 0      au  20220101       HE                 TV         4485           17
# 1      au  20220102       HA       Refrigerator         3419           20
# 2      au  20220102       HE                 TV         4676           14
# 3      au  20220103       HA  Cooking_Appliance          546            3
# 4      au  20220103       HA       Refrigerator         3691            7
#
#    sales_amt  sales_usd
# 0         10     398.96
# 1          2    1212.33
# 2          3     113.99
# 3          2     279.17
# 4          5     106.26

# %%
# rawdat의 열별 자료형을 확인합니다.
rawdat.dtypes
# Out:
# country         object
# date             int64
# category        object
# subcategory     object
# detail_page      int64
# add_to_cart      int64
# sales_amt        int64
# sales_usd      float64
# dtype: object

# %%
rawdat['date'].astype(str).astype(np.datetime64)
# Out:
# 0       2022-01-01
# 1       2022-01-02
# 2       2022-01-02
# 3       2022-01-03
# 4       2022-01-03
#            ...
# 13903   2022-12-31
# 13904   2022-12-31
# 13905   2022-12-31
# 13906   2022-12-31
# 13907   2022-12-31
# Name: date, Length: 13908, dtype: datetime64[ns]

# %%
# date를 날짜시간형(np.datetime64)으로 변환합니다.
# [주의] 날짜시간형으로 변환하려면 정수를 문자열로 먼저 변환해야 합니다.
rawdat['date'] = rawdat['date'].astype(str).astype(np.datetime64)

# %%
# date에서 월(month)을 정수로 추출하여 새로운 열로 추가합니다.
rawdat['month'] = rawdat['date'].dt.month

# %%
# date에서 월을 정수 대신 숫자(문자열)로 추출할 수 있습니다.
# [힌트] dt.strftime() 함수를 사용하세요.
rawdat['date'].dt.strftime('%m')
# Out:
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
#          ..
# 13903    12
# 13904    12
# 13905    12
# 13906    12
# 13907    12
# Name: date, Length: 13908, dtype: object

# %%
# date에서 월을 정수 대신 영문자(문자열)로 추출할 수 있습니다.
# [힌트] dt.strftime() 함수를 사용하세요.
rawdat['date'].dt.strftime('%b')
# Out:
# 0        Jan
# 1        Jan
# 2        Jan
# 3        Jan
# 4        Jan
#         ...
# 13903    Dec
# 13904    Dec
# 13905    Dec
# 13906    Dec
# 13907    Dec
# Name: date, Length: 13908, dtype: object

# %%
rawdat['date'].dt.strftime('%B')
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 13903    December
# 13904    December
# 13905    December
# 13906    December
# 13907    December
# Name: date, Length: 13908, dtype: object

# %% [markdown]
# ### 기술통계량 확인

# %%
# rawdat의 수치(정수 또는 실수)형 변수의 기술통계량을 확인합니다.
# [힌트] describe() 함수를 사용하세요.
rawdat.describe()
# Out:
#        detail_page  add_to_cart  sales_amt   sales_usd      month
# count    13908.000    13908.000  13908.000   13908.000  13908.000
# mean      2492.035       66.264      6.843    5490.174      6.748
# std       4015.041       98.457     10.850   10454.946      3.437
# min          2.000        0.000      1.000       0.010      1.000
# 25%        611.000       14.000      2.000    1056.890      4.000
# 50%       1479.500       33.000      3.000    2355.245      7.000
# 75%       3226.000       81.000      7.000    5823.302     10.000
# max     171985.000     2558.000    383.000  397796.970     12.000

# %%
# rawdat의 범주형 변수의 기술통계량을 확인합니다.
# [힌트] describe() 함수의 include 매개변수에 자료형을 지정하세요.
rawdat.describe(include = object)
# Out:
#        country category subcategory
# count    13908    13908       13908
# unique       6        3          14
# top         br       HA          TV
# freq      2694     6809        2064

# %%
# country의 빈도수를 확인합니다.
# [힌트] value_counts() 함수를 사용하세요.
rawdat['country'].value_counts()
# Out:
# br    2694
# it    2527
# uk    2443
# au    2337
# de    2017
# fr    1890
# Name: country, dtype: int64

# %%
# country의 상대도수를 확인합니다.
# [힌트] value_counts() 함수에 normalize 매개변수를 추가하세요.
rawdat['country'].value_counts(normalize = True) * 100
# Out:
# br    19.370
# it    18.169
# uk    17.565
# au    16.803
# de    14.502
# fr    13.589
# Name: country, dtype: float64

# %%
# category와 subcategory로 리스트 cols를 생성합니다.
cols = ['category', 'subcategory']

# %%
# category와 subcategory의 빈도수를 인덱스로 정렬하여 출력합니다.
# [힌트] value_counts(), sort_index() 함수를 사용하세요.
rawdat[cols].value_counts()
# Out:
# category  subcategory
# HE        TV                   2064
# BS        IT_Monitor           1892
# HA        Washer               1679
#           Refrigerator         1667
# HE        Audio_CAV            1531
# BS        IT_Laptop            1005
# HA        Cooking_Appliance     863
#           Washer_Dryer          779
#           Dryer                 730
#           Vacuum_Cleaner        371
#           Air_Conditioner       370
# BS        Monitor               359
# HA        Dishwasher            350
# BS        IT_Projector          241
# HE        Monitor                 7
# dtype: int64

# %%
rawdat[cols].value_counts().sort_index()
# Out:
# category  subcategory
# BS        IT_Laptop            1005
#           IT_Monitor           1892
#           IT_Projector          241
#           Monitor               359
# HA        Air_Conditioner       370
#           Cooking_Appliance     863
#           Dishwasher            350
#           Dryer                 730
#           Refrigerator         1667
#           Vacuum_Cleaner        371
#           Washer               1679
#           Washer_Dryer          779
# HE        Audio_CAV            1531
#           Monitor                 7
#           TV                   2064
# dtype: int64

# %% [raw]
# rawdat[cols].value_counts().sort_index().reset_index().to_excel('Frequency.xlsx')

# %%
# category와 subcategory의 상대도수를 인덱스로 정렬하여 출력합니다.
rawdat[cols].value_counts(normalize = True).sort_index()
# Out:
# category  subcategory
# BS        IT_Laptop            7.226e-02
#           IT_Monitor           1.360e-01
#           IT_Projector         1.733e-02
#           Monitor              2.581e-02
# HA        Air_Conditioner      2.660e-02
#           Cooking_Appliance    6.205e-02
#           Dishwasher           2.517e-02
#           Dryer                5.249e-02
#           Refrigerator         1.199e-01
#           Vacuum_Cleaner       2.668e-02
#           Washer               1.207e-01
#           Washer_Dryer         5.601e-02
# HE        Audio_CAV            1.101e-01
#           Monitor              5.033e-04
#           TV                   1.484e-01
# dtype: float64

# %%
# rawdat에서 빈도수 100 미만인 HE & Monitor 행을 삭제합니다.
# [힌트] 비트 연산자 &와 ~를 사용하세요.
rawdat = rawdat[~(rawdat['category'].eq('HE') & rawdat['subcategory'].eq('Monitor'))]

# %%
# rawdat의 행 개수를 출력합니다.
# [힌트] shape 속성 결과에 0번 인덱스 원소를 선택하세요.
rawdat.shape[0]
# Out:
# 13901

# %% [markdown]
# ### 국가별 페이지 유입, 장바구니 담기 및 구매 건수 확인

# %%
# 아래 조건을 만족하는 피벗 테이블을 funnel_nat에 할당합니다.
# [힌트] pd.pivot_table() 함수를 사용하세요.
# 데이터(data)는 rawdat, 
# 값(values)은 detail_page, add_to_cart와 sales_amt, 
# 행이름(index)은 country, 
# 열이름(columns)은 생략, 
# 집계함수(aggfunc)에 np.sum을 지정하세요.
funnel_nat = pd.pivot_table(
    data = rawdat,
    values = ['detail_page', 'add_to_cart', 'sales_amt'],
    index = 'country', 
    columns = None, 
    aggfunc = np.sum
)

# %%
# funnel_nat을 출력합니다.
funnel_nat
# Out:
#          add_to_cart  detail_page  sales_amt
# country
# au             65025      4948335      14196
# br            277913      9570438      28686
# de            115232      5374084      14553
# fr            130028      3862534       9084
# it            199293      5727970      12930
# uk            134093      5175668      15706

# %%
# funnel_nat의 열이름이 자동으로 정렬되었습니다.
# 열의 순서를 변경하기 위해 열이름으로 cols를 생성합니다.
cols = ['detail_page', 'add_to_cart', 'sales_amt']

# %%
# funnel_nat에 cols로 열의 순서를 변경한 결과를 출력합니다.
funnel_nat[cols]
# Out:
#          detail_page  add_to_cart  sales_amt
# country
# au           4948335        65025      14196
# br           9570438       277913      28686
# de           5374084       115232      14553
# fr           3862534       130028       9084
# it           5727970       199293      12930
# uk           5175668       134093      15706

# %%
# funnel_nat에 cols로 열의 순서를 변경한 결과를 funnel_nat에 재할당합니다.
funnel_nat = funnel_nat[cols]

# %%
# add_to_cart를 detail_page로 나누고 100을 곱한 cart_rate를 생성합니다.
funnel_nat['cart_rate'] = funnel_nat['add_to_cart'] / funnel_nat['detail_page'] * 100
# Out:
# C:\Users\hdsce\AppData\Local\Temp\ipykernel_5476\3355159556.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   funnel_nat['cart_rate'] = funnel_nat['add_to_cart'] / funnel_nat['detail_page'] * 100

# %%
# sales_amt를 add_to_cart로 나누고 100을 곱한 buy_rate1을 생성합니다.
funnel_nat['buy_rate1'] = funnel_nat['sales_amt'] / funnel_nat['add_to_cart'] * 100
# Out:
# C:\Users\hdsce\AppData\Local\Temp\ipykernel_5476\4154001465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   funnel_nat['buy_rate1'] = funnel_nat['sales_amt'] / funnel_nat['add_to_cart'] * 100

# %%
# sales_amt를 detail_page로 나누고 100을 곱한 buy_rate2를 생성합니다.
funnel_nat['buy_rate2'] = funnel_nat['sales_amt'] / funnel_nat['detail_page'] * 100
# Out:
# C:\Users\hdsce\AppData\Local\Temp\ipykernel_5476\1537234072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   funnel_nat['buy_rate2'] = funnel_nat['sales_amt'] / funnel_nat['detail_page'] * 100

# %%
# funnel_nat을 출력합니다.
funnel_nat
# Out:
#          detail_page  add_to_cart  sales_amt  cart_rate  buy_rate1  buy_rate2
# country
# au           4948335        65025      14196      1.314     21.832      0.287
# br           9570438       277913      28686      2.904     10.322      0.300
# de           5374084       115232      14553      2.144     12.629      0.271
# fr           3862534       130028       9084      3.366      6.986      0.235
# it           5727970       199293      12930      3.479      6.488      0.226
# uk           5175668       134093      15706      2.591     11.713      0.303

# %%
# funnel_nat을 cart_rate로 내림차순 정렬한 결과를 출력합니다.
funnel_nat.sort_values(by = ['cart_rate'], ascending = False)
# Out:
#          detail_page  add_to_cart  sales_amt  cart_rate  buy_rate1  buy_rate2
# country
# it           5727970       199293      12930      3.479      6.488      0.226
# fr           3862534       130028       9084      3.366      6.986      0.235
# br           9570438       277913      28686      2.904     10.322      0.300
# uk           5175668       134093      15706      2.591     11.713      0.303
# de           5374084       115232      14553      2.144     12.629      0.271
# au           4948335        65025      14196      1.314     21.832      0.287

# %%
# funnel_nat을 buy_rate1으로 내림차순 정렬한 결과를 출력합니다.
funnel_nat.sort_values(by = ['buy_rate1'], ascending = False)
# Out:
#          detail_page  add_to_cart  sales_amt  cart_rate  buy_rate1  buy_rate2
# country
# au           4948335        65025      14196      1.314     21.832      0.287
# de           5374084       115232      14553      2.144     12.629      0.271
# uk           5175668       134093      15706      2.591     11.713      0.303
# br           9570438       277913      28686      2.904     10.322      0.300
# fr           3862534       130028       9084      3.366      6.986      0.235
# it           5727970       199293      12930      3.479      6.488      0.226

# %%
# funnel_nat을 buy_rate2로 내림차순 정렬한 결과를 출력합니다.
funnel_nat.sort_values(by = ['buy_rate2'], ascending = False)
# Out:
#          detail_page  add_to_cart  sales_amt  cart_rate  buy_rate1  buy_rate2
# country
# uk           5175668       134093      15706      2.591     11.713      0.303
# br           9570438       277913      28686      2.904     10.322      0.300
# au           4948335        65025      14196      1.314     21.832      0.287
# de           5374084       115232      14553      2.144     12.629      0.271
# fr           3862534       130028       9084      3.366      6.986      0.235
# it           5727970       199293      12930      3.479      6.488      0.226

# %% [markdown]
# ### 제품별 페이지 유입, 장바구니 담기 및 구매 건수 확인

# %%
# 아래 조건을 만족하는 피벗 테이블을 funnel_prd에 할당합니다.
# [힌트] pd.pivot_table() 함수를 사용하세요.
# 데이터(data)는 rawdat, 
# 값(values)은 detail_page, add_to_cart와 sales_amt, 
# 행이름(index)은 category, subcategory, 
# 열이름(columns)은 생략, 
# 집계함수(aggfunc)에 np.sum, 
# 정렬(sort)에 False를 지정하세요.
funnel_prd = pd.pivot_table(
    data = rawdat,
    values = ['detail_page', 'add_to_cart', 'sales_amt'],
    index = ['category', 'subcategory'],
    columns = None,
    aggfunc = np.sum, 
    sort = False
)

# %%
# funnel_prd을 출력합니다.
funnel_prd
# Out:
#                             detail_page  add_to_cart  sales_amt
# category subcategory
# HE       TV                    14050004       404417      33582
# HA       Refrigerator           5455927       115179       7961
#          Cooking_Appliance       593693        16584       3319
# HE       Audio_CAV              3502572        83959       8347
# HA       Dishwasher              124291         3385        836
#          Washer                 3308513        98899      11023
#          Washer_Dryer            563739        16284       1949
#          Dryer                   340903        18038       2814
#          Vacuum_Cleaner          272622         7293       1239
# BS       Monitor                 379783         6228       1762
#          IT_Monitor             3489645        90001      16489
#          IT_Laptop               471336        22462       3572
# HA       Air_Conditioner        2053843        36432       1710
# BS       IT_Projector             52158         2423        552

# %%
# add_to_cart를 detail_page로 나누고 100을 곱한 cart_rate를 생성합니다.
funnel_prd['cart_rate'] = funnel_prd['add_to_cart'] / funnel_prd['detail_page'] * 100

# %%
# sales_amt를 add_to_cart로 나누고 100을 곱한 buy_rate1을 생성합니다.
funnel_prd['buy_rate1'] = funnel_prd['sales_amt'] / funnel_prd['add_to_cart'] * 100

# %%
# sales_amt를 detail_page로 나누고 100을 곱한 buy_rate2를 생성합니다.
funnel_prd['buy_rate2'] = funnel_prd['sales_amt'] / funnel_prd['detail_page'] * 100

# %%
# funnel_prd을 출력합니다.
funnel_prd
# Out:
#                             detail_page  add_to_cart  sales_amt  cart_rate  \
# category subcategory
# HE       TV                    14050004       404417      33582      2.878
# HA       Refrigerator           5455927       115179       7961      2.111
#          Cooking_Appliance       593693        16584       3319      2.793
# HE       Audio_CAV              3502572        83959       8347      2.397
# HA       Dishwasher              124291         3385        836      2.723
#          Washer                 3308513        98899      11023      2.989
#          Washer_Dryer            563739        16284       1949      2.889
#          Dryer                   340903        18038       2814      5.291
#          Vacuum_Cleaner          272622         7293       1239      2.675
# BS       Monitor                 379783         6228       1762      1.640
#          IT_Monitor             3489645        90001      16489      2.579
#          IT_Laptop               471336        22462       3572      4.766
# HA       Air_Conditioner        2053843        36432       1710      1.774
# BS       IT_Projector             52158         2423        552      4.646
#
#                             buy_rate1  buy_rate2
# category subcategory
# HE       TV                     8.304      0.239
# HA       Refrigerator           6.912      0.146
#          Cooking_Appliance     20.013      0.559
# HE       Audio_CAV              9.942      0.238
# HA       Dishwasher            24.697      0.673
#          Washer                11.146      0.333
#          Washer_Dryer          11.969      0.346
#          Dryer                 15.600      0.825
#          Vacuum_Cleaner        16.989      0.454
# BS       Monitor               28.292      0.464
#          IT_Monitor            18.321      0.473
#          IT_Laptop             15.902      0.758
# HA       Air_Conditioner        4.694      0.083
# BS       IT_Projector          22.782      1.058

# %%
# funnel_prd을 cart_rate로 내림차순 정렬한 결과를 출력합니다.
funnel_prd.sort_values(by = ['cart_rate'], ascending = False)
# Out:
#                             detail_page  add_to_cart  sales_amt  cart_rate  \
# category subcategory
# HA       Dryer                   340903        18038       2814      5.291
# BS       IT_Laptop               471336        22462       3572      4.766
#          IT_Projector             52158         2423        552      4.646
# HA       Washer                 3308513        98899      11023      2.989
#          Washer_Dryer            563739        16284       1949      2.889
# HE       TV                    14050004       404417      33582      2.878
# HA       Cooking_Appliance       593693        16584       3319      2.793
#          Dishwasher              124291         3385        836      2.723
#          Vacuum_Cleaner          272622         7293       1239      2.675
# BS       IT_Monitor             3489645        90001      16489      2.579
# HE       Audio_CAV              3502572        83959       8347      2.397
# HA       Refrigerator           5455927       115179       7961      2.111
#          Air_Conditioner        2053843        36432       1710      1.774
# BS       Monitor                 379783         6228       1762      1.640
#
#                             buy_rate1  buy_rate2
# category subcategory
# HA       Dryer                 15.600      0.825
# BS       IT_Laptop             15.902      0.758
#          IT_Projector          22.782      1.058
# HA       Washer                11.146      0.333
#          Washer_Dryer          11.969      0.346
# HE       TV                     8.304      0.239
# HA       Cooking_Appliance     20.013      0.559
#          Dishwasher            24.697      0.673
#          Vacuum_Cleaner        16.989      0.454
# BS       IT_Monitor            18.321      0.473
# HE       Audio_CAV              9.942      0.238
# HA       Refrigerator           6.912      0.146
#          Air_Conditioner        4.694      0.083
# BS       Monitor               28.292      0.464

# %%
# funnel_prd을 buy_rate1으로 내림차순 정렬한 결과를 출력합니다.
funnel_prd.sort_values(by = ['buy_rate1'], ascending = False)
# Out:
#                             detail_page  add_to_cart  sales_amt  cart_rate  \
# category subcategory
# BS       Monitor                 379783         6228       1762      1.640
# HA       Dishwasher              124291         3385        836      2.723
# BS       IT_Projector             52158         2423        552      4.646
# HA       Cooking_Appliance       593693        16584       3319      2.793
# BS       IT_Monitor             3489645        90001      16489      2.579
# HA       Vacuum_Cleaner          272622         7293       1239      2.675
# BS       IT_Laptop               471336        22462       3572      4.766
# HA       Dryer                   340903        18038       2814      5.291
#          Washer_Dryer            563739        16284       1949      2.889
#          Washer                 3308513        98899      11023      2.989
# HE       Audio_CAV              3502572        83959       8347      2.397
#          TV                    14050004       404417      33582      2.878
# HA       Refrigerator           5455927       115179       7961      2.111
#          Air_Conditioner        2053843        36432       1710      1.774
#
#                             buy_rate1  buy_rate2
# category subcategory
# BS       Monitor               28.292      0.464
# HA       Dishwasher            24.697      0.673
# BS       IT_Projector          22.782      1.058
# HA       Cooking_Appliance     20.013      0.559
# BS       IT_Monitor            18.321      0.473
# HA       Vacuum_Cleaner        16.989      0.454
# BS       IT_Laptop             15.902      0.758
# HA       Dryer                 15.600      0.825
#          Washer_Dryer          11.969      0.346
#          Washer                11.146      0.333
# HE       Audio_CAV              9.942      0.238
#          TV                     8.304      0.239
# HA       Refrigerator           6.912      0.146
#          Air_Conditioner        4.694      0.083

# %%
# funnel_prd을 buy_rate2로 내림차순 정렬한 결과를 출력합니다.
funnel_prd.sort_values(by = ['buy_rate2'], ascending = False)
# Out:
#                             detail_page  add_to_cart  sales_amt  cart_rate  \
# category subcategory
# BS       IT_Projector             52158         2423        552      4.646
# HA       Dryer                   340903        18038       2814      5.291
# BS       IT_Laptop               471336        22462       3572      4.766
# HA       Dishwasher              124291         3385        836      2.723
#          Cooking_Appliance       593693        16584       3319      2.793
# BS       IT_Monitor             3489645        90001      16489      2.579
#          Monitor                 379783         6228       1762      1.640
# HA       Vacuum_Cleaner          272622         7293       1239      2.675
#          Washer_Dryer            563739        16284       1949      2.889
#          Washer                 3308513        98899      11023      2.989
# HE       TV                    14050004       404417      33582      2.878
#          Audio_CAV              3502572        83959       8347      2.397
# HA       Refrigerator           5455927       115179       7961      2.111
#          Air_Conditioner        2053843        36432       1710      1.774
#
#                             buy_rate1  buy_rate2
# category subcategory
# BS       IT_Projector          22.782      1.058
# HA       Dryer                 15.600      0.825
# BS       IT_Laptop             15.902      0.758
# HA       Dishwasher            24.697      0.673
#          Cooking_Appliance     20.013      0.559
# BS       IT_Monitor            18.321      0.473
#          Monitor               28.292      0.464
# HA       Vacuum_Cleaner        16.989      0.454
#          Washer_Dryer          11.969      0.346
#          Washer                11.146      0.333
# HE       TV                     8.304      0.239
#          Audio_CAV              9.942      0.238
# HA       Refrigerator           6.912      0.146
#          Air_Conditioner        4.694      0.083

# %% [markdown]
# ### 국가별 판매대수와 판매금액 합계 계산

# %%
# 아래 조건을 만족하는 피벗 테이블을 price_nat에 할당합니다.
# [힌트] pd.pivot_table() 함수를 사용하세요.
# 데이터(data)는 rawdat, 
# 값(values)은 sales_amt와 sales_usd, 
# 행이름(index)은 country, 
# 열이름(columns)은 생략, 
# 집계함수(aggfunc)에 np.sum을 지정하세요.
price_nat = pd.pivot_table(
    data = rawdat, 
    values = ['sales_amt', 'sales_usd'], 
    index = 'country', 
    columns = None, 
    aggfunc = np.sum
)

# %%
# price_nat을 출력합니다.
price_nat
# Out:
#          sales_amt  sales_usd
# country
# au           14196  7.555e+06
# br           28686  2.210e+07
# de           14553  1.232e+07
# fr            9084  8.166e+06
# it           12930  1.099e+07
# uk           15706  1.522e+07

# %%
# sales_usd를 sales_amt로 나눈 avg_price를 생성합니다.
price_nat['avg_price'] = price_nat['sales_usd'] / price_nat['sales_amt']

# %%
# price_nat을 sales_amt로 내림차순 정렬한 결과를 출력합니다.
price_nat.sort_values(by = ['sales_amt'], ascending = False)
# Out:
#          sales_amt  sales_usd  avg_price
# country
# br           28686  2.210e+07    770.460
# uk           15706  1.522e+07    969.006
# de           14553  1.232e+07    846.429
# au           14196  7.555e+06    532.198
# it           12930  1.099e+07    850.177
# fr            9084  8.166e+06    898.983

# %%
# price_nat을 sales_usd로 내림차순 정렬한 결과를 출력합니다.
price_nat.sort_values(by = ['sales_usd'], ascending = False)
# Out:
#          sales_amt  sales_usd  avg_price
# country
# br           28686  2.210e+07    770.460
# uk           15706  1.522e+07    969.006
# de           14553  1.232e+07    846.429
# it           12930  1.099e+07    850.177
# fr            9084  8.166e+06    898.983
# au           14196  7.555e+06    532.198

# %%
# price_nat을 avg_price로 내림차순 정렬한 결과를 출력합니다.
price_nat.sort_values(by = ['avg_price'], ascending = False)
# Out:
#          sales_amt  sales_usd  avg_price
# country
# uk           15706  1.522e+07    969.006
# fr            9084  8.166e+06    898.983
# it           12930  1.099e+07    850.177
# de           14553  1.232e+07    846.429
# br           28686  2.210e+07    770.460
# au           14196  7.555e+06    532.198

# %% [markdown]
# ### 제품별 판매대수와 판매금액 합계 계산

# %%
# 아래 조건을 만족하는 피벗 테이블을 price_prd에 할당합니다.
# [힌트] pd.pivot_table() 함수를 사용하세요.
# 데이터(data)는 rawdat에서 country가 'au'인 행을 선택, 
# 값(values)은 sales_amt와 sales_usd, 
# 행이름(index)은 category와 subcategory, 
# 열이름(columns)은 생략, 
# 집계함수(aggfunc)에 np.sum을 지정하세요.
price_prd = pd.pivot_table(
    data = rawdat[rawdat['country'].eq('au')],
    values = ['sales_amt', 'sales_usd'], 
    index = ['category', 'subcategory'], 
    columns = None, 
    aggfunc = np.sum
)

# %%
# price_prd의 처음 5행을 출력합니다.
price_prd.head()
# Out:
#                             sales_amt  sales_usd
# category subcategory
# BS       IT_Laptop                107  120568.37
#          IT_Monitor               707  357615.10
#          Monitor                  262   78368.61
# HA       Cooking_Appliance        717  130168.31
#          Dishwasher               386  237703.44

# %%
# price_prd의 행 개수를 출력합니다.
# [힌트] shape 속성 결과에 0번 인덱스 원소를 선택하세요.
price_prd.shape[0]
# Out:
# 12

# %%
# price_prd의 열별 결측값 개수를 확인합니다.
# [힌트] isna() 함수를 사용하세요.
price_prd.isna().sum()
# Out:
# sales_amt    0
# sales_usd    0
# dtype: int64

# %%
# price_prd에 있는 결측값을 0으로 대체하고 price_prd에 재할당합니다.
# [힌트] fillna() 함수를 사용하세요.
price_prd = price_prd.fillna(value = 0)

# %%
# sales_usd를 sales_amt로 나눈 avg_price를 생성합니다.
price_prd['avg_price'] = price_prd['sales_usd'] / price_prd['sales_amt']

# %%
# price_prd를 avg_price로 내림차순 정렬하고 price_prd에 재할당합니다.
# [힌트] sort_values() 함수를 사용하세요.
price_prd = price_prd.sort_values(by = ['avg_price'], ascending = False)

# %%
# price_prd를 출력합니다.
price_prd
# Out:
#                             sales_amt  sales_usd  avg_price
# category subcategory
# BS       IT_Laptop                107  1.206e+05   1126.807
# HA       Dryer                    567  4.475e+05    789.268
#          Refrigerator            2320  1.705e+06    735.114
#          Washer                  1248  8.470e+05    678.646
#          Dishwasher               386  2.377e+05    615.812
#          Washer_Dryer             182  1.042e+05    572.673
# BS       IT_Monitor               707  3.576e+05    505.821
# HE       TV                      6240  3.071e+06    492.149
#          Audio_CAV                628  2.076e+05    330.507
# BS       Monitor                  262  7.837e+04    299.117
# HA       Vacuum_Cleaner           832  2.479e+05    298.003
#          Cooking_Appliance        717  1.302e+05    181.546

# %%
# price_prd의 행이름을 초기화한 결과를 출력합니다.
# [힌트] reset_index() 함수를 사용하세요.
# [참고] 기존 행이름을 맨 처음 열로 추가합니다.
# [참고] drop = True를 추가하면 기존 행이름을 삭제합니다.
price_prd.reset_index()
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        BS          IT_Laptop        107  1.206e+05   1126.807
# 1        HA              Dryer        567  4.475e+05    789.268
# 2        HA       Refrigerator       2320  1.705e+06    735.114
# 3        HA             Washer       1248  8.470e+05    678.646
# 4        HA         Dishwasher        386  2.377e+05    615.812
# 5        HA       Washer_Dryer        182  1.042e+05    572.673
# 6        BS         IT_Monitor        707  3.576e+05    505.821
# 7        HE                 TV       6240  3.071e+06    492.149
# 8        HE          Audio_CAV        628  2.076e+05    330.507
# 9        BS            Monitor        262  7.837e+04    299.117
# 10       HA     Vacuum_Cleaner        832  2.479e+05    298.003
# 11       HA  Cooking_Appliance        717  1.302e+05    181.546

# %%
# price_prd의 행이름을 초기화하고 price_prd에 재할당합니다.
price_prd = price_prd.reset_index()

# %%
# price_prd의 처음 7행을 출력합니다.(평균 가격 상위 7개)
price_prd.head(n = 7)
# Out:
#   category   subcategory  sales_amt  sales_usd  avg_price
# 0       BS     IT_Laptop        107  1.206e+05   1126.807
# 1       HA         Dryer        567  4.475e+05    789.268
# 2       HA  Refrigerator       2320  1.705e+06    735.114
# 3       HA        Washer       1248  8.470e+05    678.646
# 4       HA    Dishwasher        386  2.377e+05    615.812
# 5       HA  Washer_Dryer        182  1.042e+05    572.673
# 6       BS    IT_Monitor        707  3.576e+05    505.821

# %%
# price_prd의 마지막 7행을 출력합니다.(평균 가격 하위 7개)
price_prd.tail(n = 7)
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 5        HA       Washer_Dryer        182  1.042e+05    572.673
# 6        BS         IT_Monitor        707  3.576e+05    505.821
# 7        HE                 TV       6240  3.071e+06    492.149
# 8        HE          Audio_CAV        628  2.076e+05    330.507
# 9        BS            Monitor        262  7.837e+04    299.117
# 10       HA     Vacuum_Cleaner        832  2.479e+05    298.003
# 11       HA  Cooking_Appliance        717  1.302e+05    181.546

# %% [markdown]
# ### 지정한 국가의 제품별 평균 가격을 반환하는 함수 생성

# %%
# 국가명을 지정하면 수산물품목별 무역수지를 반환하는 함수를 생성합니다.
def getAvgPrice(nation):
    
    # rawdat에서 contry가 nation인 행을 선택한 다음
    # 피벗 테이블을 생성하고 price_prd에 할당합니다.
    price_prd = pd.pivot_table(
        data = rawdat[rawdat['country'].eq(nation)],
        values = ['sales_amt', 'sales_usd'], 
        index = ['category', 'subcategory'], 
        columns = None, 
        aggfunc = np.sum
    )
    
    # price_prd에 있는 결측값을 0으로 대체하고 price_prd에 재할당합니다.
    price_prd = price_prd.fillna(value = 0)
    
    # sales_usd를 sales_amt로 나눈 avg_price를 생성합니다.
    price_prd['avg_price'] = price_prd['sales_usd'] / price_prd['sales_amt']
    
    # price_prd를 avg_price로 내림차순 정렬하고 price_prd에 재할당합니다.
    # [힌트] sort_values() 함수를 사용하세요.
    price_prd = price_prd.sort_values(by = ['avg_price'], ascending = False)
    
    # price_prd의 행이름을 초기화하고 price_prd에 재할당합니다.
    price_prd = price_prd.reset_index()

    # 결과를 반환합니다.
    return price_prd

# %%
# 호주의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'au')
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        BS          IT_Laptop        107  1.206e+05   1126.807
# 1        HA              Dryer        567  4.475e+05    789.268
# 2        HA       Refrigerator       2320  1.705e+06    735.114
# 3        HA             Washer       1248  8.470e+05    678.646
# 4        HA         Dishwasher        386  2.377e+05    615.812
# 5        HA       Washer_Dryer        182  1.042e+05    572.673
# 6        BS         IT_Monitor        707  3.576e+05    505.821
# 7        HE                 TV       6240  3.071e+06    492.149
# 8        HE          Audio_CAV        628  2.076e+05    330.507
# 9        BS            Monitor        262  7.837e+04    299.117
# 10       HA     Vacuum_Cleaner        832  2.479e+05    298.003
# 11       HA  Cooking_Appliance        717  1.302e+05    181.546

# %%
# 브라질의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'br')
# Out:
#   category        subcategory  sales_amt  sales_usd  avg_price
# 0       HA       Refrigerator        746  1.761e+06   2360.557
# 1       HA       Washer_Dryer        223  4.975e+05   2230.826
# 2       BS          IT_Laptop        631  6.634e+05   1051.393
# 3       HA             Washer       5506  4.996e+06    907.343
# 4       HE                 TV      13974  1.163e+07    832.114
# 5       BS       IT_Projector        333  1.973e+05    592.546
# 6       HA    Air_Conditioner       1575  8.947e+05    568.054
# 7       BS         IT_Monitor       1774  5.882e+05    331.562
# 8       HE          Audio_CAV       2423  6.783e+05    279.957
# 9       HA  Cooking_Appliance       1501  1.972e+05    131.392

# %%
# 독일의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'de')
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        HE                 TV       2745  4.563e+06   1662.176
# 1        BS       IT_Projector         99  1.526e+05   1541.818
# 2        BS          IT_Laptop        961  1.127e+06   1172.297
# 3        HA       Washer_Dryer        234  2.528e+05   1080.418
# 4        HA       Refrigerator        730  7.305e+05   1000.687
# 5        HA              Dryer        206  1.459e+05    708.474
# 6        BS            Monitor       1212  7.898e+05    651.655
# 7        BS         IT_Monitor       6430  3.934e+06    611.773
# 8        HA    Air_Conditioner         44  2.467e+04    560.771
# 9        HA             Washer        611  3.368e+05    551.198
# 10       HA     Vacuum_Cleaner         24  1.297e+04    540.307
# 11       HE          Audio_CAV        895  2.202e+05    246.082
# 12       HA  Cooking_Appliance        362  2.876e+04     79.449

# %%
# 프랑스의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'fr')
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        BS       IT_Projector         64  1.127e+05   1761.166
# 1        HE                 TV       2976  4.018e+06   1350.125
# 2        HA       Refrigerator        541  6.937e+05   1282.165
# 3        BS          IT_Laptop        785  9.812e+05   1249.921
# 4        HA       Washer_Dryer        201  1.960e+05    975.074
# 5        HA              Dryer        100  8.257e+04    825.729
# 6        HA             Washer        377  3.057e+05    810.946
# 7        HA         Dishwasher        141  1.000e+05    709.531
# 8        BS         IT_Monitor       2339  1.201e+06    513.633
# 9        BS            Monitor         38  1.664e+04    437.815
# 10       HA     Vacuum_Cleaner         93  3.916e+04    421.049
# 11       HE          Audio_CAV       1233  3.776e+05    306.226
# 12       HA  Cooking_Appliance        196  4.175e+04    212.998

# %%
# 이탈리아의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'it')
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        HE                 TV       3167  4.564e+06   1441.088
# 1        HA       Refrigerator       2082  2.532e+06   1215.957
# 2        BS          IT_Laptop        181  1.724e+05    952.378
# 3        HA    Air_Conditioner         91  7.801e+04    857.236
# 4        HA       Washer_Dryer        440  3.407e+05    774.314
# 5        BS       IT_Projector          8  6.193e+03    774.145
# 6        HA              Dryer       1433  9.413e+05    656.889
# 7        HA         Dishwasher        269  1.676e+05    623.196
# 8        HA             Washer       1976  1.227e+06    621.037
# 9        HA     Vacuum_Cleaner        290  1.363e+05    470.040
# 10       BS         IT_Monitor       1670  5.300e+05    317.386
# 11       HE          Audio_CAV        576  1.716e+05    298.001
# 12       BS            Monitor        204  4.769e+04    233.774
# 13       HA  Cooking_Appliance        543  7.815e+04    143.917

# %%
# 영국의 제품별 평균 가격을 출력합니다.
getAvgPrice(nation = 'uk')
# Out:
#    category   subcategory  sales_amt  sales_usd  avg_price
# 0        HA  Refrigerator       1542  2.851e+06   1848.933
# 1        BS  IT_Projector         48  7.713e+04   1606.898
# 2        HE            TV       4480  6.078e+06   1356.766
# 3        HA         Dryer        508  6.172e+05   1214.910
# 4        HA    Dishwasher         40  4.263e+04   1065.841
# 5        BS     IT_Laptop        907  9.630e+05   1061.790
# 6        HA  Washer_Dryer        669  6.902e+05   1031.681
# 7        HA        Washer       1305  1.208e+06    925.608
# 8        BS       Monitor         46  3.422e+04    743.961
# 9        BS    IT_Monitor       3569  2.043e+06    572.367
# 10       HE     Audio_CAV       2592  6.148e+05    237.172

# %% [markdown]
# ### 데이터 병합

# %%
# rawdat에서 category와 subcategory의 빈도수를 계산하여 merged에 할당합니다.
merged = rawdat[['category', 'subcategory']].value_counts()

# %%
# merged를 출력합니다.
merged
# Out:
# category  subcategory
# HE        TV                   2064
# BS        IT_Monitor           1892
# HA        Washer               1679
#           Refrigerator         1667
# HE        Audio_CAV            1531
# BS        IT_Laptop            1005
# HA        Cooking_Appliance     863
#           Washer_Dryer          779
#           Dryer                 730
#           Vacuum_Cleaner        371
#           Air_Conditioner       370
# BS        Monitor               359
# HA        Dishwasher            350
# BS        IT_Projector          241
# dtype: int64

# %%
# merged의 행이름을 초기화한 결과를 출력합니다.
# [참고] 시리즈의 행이름을 초기화하면 데이터프레임을 반환합니다.
merged.reset_index()
# Out:
#    category        subcategory     0
# 0        HE                 TV  2064
# 1        BS         IT_Monitor  1892
# 2        HA             Washer  1679
# 3        HA       Refrigerator  1667
# 4        HE          Audio_CAV  1531
# 5        BS          IT_Laptop  1005
# 6        HA  Cooking_Appliance   863
# 7        HA       Washer_Dryer   779
# 8        HA              Dryer   730
# 9        HA     Vacuum_Cleaner   371
# 10       HA    Air_Conditioner   370
# 11       BS            Monitor   359
# 12       HA         Dishwasher   350
# 13       BS       IT_Projector   241

# %%
# merged의 행이름을 초기화한 결과를 merged에 재할당합니다.
merged = merged.reset_index()

# %%
# merged에서 정수 0인 열이름을 삭제합니다.
merged = merged.drop(columns = [0])

# %%
merged
# Out:
#    category        subcategory
# 0        HE                 TV
# 1        BS         IT_Monitor
# 2        HA             Washer
# 3        HA       Refrigerator
# 4        HE          Audio_CAV
# 5        BS          IT_Laptop
# 6        HA  Cooking_Appliance
# 7        HA       Washer_Dryer
# 8        HA              Dryer
# 9        HA     Vacuum_Cleaner
# 10       HA    Air_Conditioner
# 11       BS            Monitor
# 12       HA         Dishwasher
# 13       BS       IT_Projector

# %%
# 호주의 국가명을 nation에 할당합니다.
nation = 'au'

# %%
# 호주의 제품별 평균 가격 데이터를 price_prd로 생성합니다.
price_prd = getAvgPrice(nation)

# %%
# price_prd를 출력합니다.
price_prd
# Out:
#    category        subcategory  sales_amt  sales_usd  avg_price
# 0        BS          IT_Laptop        107  1.206e+05   1126.807
# 1        HA              Dryer        567  4.475e+05    789.268
# 2        HA       Refrigerator       2320  1.705e+06    735.114
# 3        HA             Washer       1248  8.470e+05    678.646
# 4        HA         Dishwasher        386  2.377e+05    615.812
# 5        HA       Washer_Dryer        182  1.042e+05    572.673
# 6        BS         IT_Monitor        707  3.576e+05    505.821
# 7        HE                 TV       6240  3.071e+06    492.149
# 8        HE          Audio_CAV        628  2.076e+05    330.507
# 9        BS            Monitor        262  7.837e+04    299.117
# 10       HA     Vacuum_Cleaner        832  2.479e+05    298.003
# 11       HA  Cooking_Appliance        717  1.302e+05    181.546

# %%
# price_prd의 일부 열이름을 아래와 같이 변경합니다.
# sales_amt -> amt_au
# sales_usd -> usd_au
# avg_price -> avg_au
# [힌트] rename() 함수와 f-문자열을 사용하세요.
price_prd = price_prd.rename(columns = {
    'sales_amt': f'amt_{nation}',
    'sales_usd': f'usd_{nation}',
    'avg_price': f'avg_{nation}'
})

# %%
price_prd
# Out:
#    category        subcategory  amt_au     usd_au    avg_au
# 0        BS          IT_Laptop     107  1.206e+05  1126.807
# 1        HA              Dryer     567  4.475e+05   789.268
# 2        HA       Refrigerator    2320  1.705e+06   735.114
# 3        HA             Washer    1248  8.470e+05   678.646
# 4        HA         Dishwasher     386  2.377e+05   615.812
# 5        HA       Washer_Dryer     182  1.042e+05   572.673
# 6        BS         IT_Monitor     707  3.576e+05   505.821
# 7        HE                 TV    6240  3.071e+06   492.149
# 8        HE          Audio_CAV     628  2.076e+05   330.507
# 9        BS            Monitor     262  7.837e+04   299.117
# 10       HA     Vacuum_Cleaner     832  2.479e+05   298.003
# 11       HA  Cooking_Appliance     717  1.302e+05   181.546

# %%
# merged와 price_prd의 제품별 평균 가격 데이터를 외부병합합니다.
# [참고] 결측값(NaN)은 해당 국가에 관련 데이터가 없다는 것을 의미합니다.
pd.merge(left = merged, 
         right = price_prd, 
         how = 'outer', 
         on = ['category', 'subcategory'])
# Out:
#    category        subcategory  amt_au     usd_au    avg_au
# 0        HE                 TV  6240.0  3.071e+06   492.149
# 1        BS         IT_Monitor   707.0  3.576e+05   505.821
# 2        HA             Washer  1248.0  8.470e+05   678.646
# 3        HA       Refrigerator  2320.0  1.705e+06   735.114
# 4        HE          Audio_CAV   628.0  2.076e+05   330.507
# 5        BS          IT_Laptop   107.0  1.206e+05  1126.807
# 6        HA  Cooking_Appliance   717.0  1.302e+05   181.546
# 7        HA       Washer_Dryer   182.0  1.042e+05   572.673
# 8        HA              Dryer   567.0  4.475e+05   789.268
# 9        HA     Vacuum_Cleaner   832.0  2.479e+05   298.003
# 10       HA    Air_Conditioner     NaN        NaN       NaN
# 11       BS            Monitor   262.0  7.837e+04   299.117
# 12       HA         Dishwasher   386.0  2.377e+05   615.812
# 13       BS       IT_Projector     NaN        NaN       NaN

# %%
# 반복문을 실행할 범위(국가명 리스트)를 nations에 할당합니다.
# [힌트] unique() 함수를 사용하세요.
nations = rawdat['country'].unique()

# %%
# nations을 출력합니다.
nations
# Out:
# array(['au', 'br', 'de', 'fr', 'it', 'uk'], dtype=object)

# %%
# nations의 원소를 출력하는 for 반복문을 실행합니다.
for nation in nations:
    print(nation)
# Out:
# au
# br
# de
# fr
# it
# uk

# %%
# nations의 원소를 바꿔가면서 merged에 병합합니다.
for nation in nations:
    
    # nation의 제품별 평균 가격 데이터를 price_prd로 생성합니다.
    price_prd = getAvgPrice(nation)
    
    # price_prd의 일부 열이름을 변경합니다.
    price_prd = price_prd.rename(columns = {
        'sales_amt': f'amt_{nation}',
        'sales_usd': f'usd_{nation}',
        'avg_price': f'avg_{nation}'
    })
    
    # merged와 price_prd의 제품별 평균 가격 데이터를 외부병합합니다.
    merged = pd.merge(
        left = merged, 
        right = price_prd, 
        how = 'outer', 
        on = ['category', 'subcategory']
    )

# %%
# merged를 출력합니다.
merged
# Out:
#    category        subcategory  amt_au     usd_au    avg_au   amt_br  \
# 0        HE                 TV  6240.0  3.071e+06   492.149  13974.0
# 1        BS         IT_Monitor   707.0  3.576e+05   505.821   1774.0
# 2        HA             Washer  1248.0  8.470e+05   678.646   5506.0
# 3        HA       Refrigerator  2320.0  1.705e+06   735.114    746.0
# 4        HE          Audio_CAV   628.0  2.076e+05   330.507   2423.0
# 5        BS          IT_Laptop   107.0  1.206e+05  1126.807    631.0
# 6        HA  Cooking_Appliance   717.0  1.302e+05   181.546   1501.0
# 7        HA       Washer_Dryer   182.0  1.042e+05   572.673    223.0
# 8        HA              Dryer   567.0  4.475e+05   789.268      NaN
# 9        HA     Vacuum_Cleaner   832.0  2.479e+05   298.003      NaN
# 10       HA    Air_Conditioner     NaN        NaN       NaN   1575.0
# 11       BS            Monitor   262.0  7.837e+04   299.117      NaN
# 12       HA         Dishwasher   386.0  2.377e+05   615.812      NaN
# 13       BS       IT_Projector     NaN        NaN       NaN    333.0
#
#        usd_br    avg_br  amt_de     usd_de    avg_de  amt_fr     usd_fr  \
# 0   1.163e+07   832.114  2745.0  4.563e+06  1662.176  2976.0  4.018e+06
# 1   5.882e+05   331.562  6430.0  3.934e+06   611.773  2339.0  1.201e+06
# 2   4.996e+06   907.343   611.0  3.368e+05   551.198   377.0  3.057e+05
# 3   1.761e+06  2360.557   730.0  7.305e+05  1000.687   541.0  6.937e+05
# 4   6.783e+05   279.957   895.0  2.202e+05   246.082  1233.0  3.776e+05
# 5   6.634e+05  1051.393   961.0  1.127e+06  1172.297   785.0  9.812e+05
# 6   1.972e+05   131.392   362.0  2.876e+04    79.449   196.0  4.175e+04
# 7   4.975e+05  2230.826   234.0  2.528e+05  1080.418   201.0  1.960e+05
# 8         NaN       NaN   206.0  1.459e+05   708.474   100.0  8.257e+04
# 9         NaN       NaN    24.0  1.297e+04   540.307    93.0  3.916e+04
# 10  8.947e+05   568.054    44.0  2.467e+04   560.771     NaN        NaN
# 11        NaN       NaN  1212.0  7.898e+05   651.655    38.0  1.664e+04
# 12        NaN       NaN     NaN        NaN       NaN   141.0  1.000e+05
# 13  1.973e+05   592.546    99.0  1.526e+05  1541.818    64.0  1.127e+05
#
#       avg_fr  amt_it     usd_it    avg_it  amt_uk     usd_uk    avg_uk
# 0   1350.125    3167  4.564e+06  1441.088  4480.0  6.078e+06  1356.766
# 1    513.633    1670  5.300e+05   317.386  3569.0  2.043e+06   572.367
# 2    810.946    1976  1.227e+06   621.037  1305.0  1.208e+06   925.608
# 3   1282.165    2082  2.532e+06  1215.957  1542.0  2.851e+06  1848.933
# 4    306.226     576  1.716e+05   298.001  2592.0  6.148e+05   237.172
# 5   1249.921     181  1.724e+05   952.378   907.0  9.630e+05  1061.790
# 6    212.998     543  7.815e+04   143.917     NaN        NaN       NaN
# 7    975.074     440  3.407e+05   774.314   669.0  6.902e+05  1031.681
# 8    825.729    1433  9.413e+05   656.889   508.0  6.172e+05  1214.910
# 9    421.049     290  1.363e+05   470.040     NaN        NaN       NaN
# 10       NaN      91  7.801e+04   857.236     NaN        NaN       NaN
# 11   437.815     204  4.769e+04   233.774    46.0  3.422e+04   743.961
# 12   709.531     269  1.676e+05   623.196    40.0  4.263e+04  1065.841
# 13  1761.166       8  6.193e+03   774.145    48.0  7.713e+04  1606.898

# %%
# merged에서 category와 subcategory를 인덱스로 설정합니다.
# [힌트] set_index() 함수를 사용하세요.
merged =

# %%
# merged의 열이름을 출력합니다.

# %% [markdown]
# ### 데이터 결합

# %%
# merged의 열이름에서 'amt'를 포함하는 원소만 남겨 col_amt에 할당합니다.
# [힌트] 리스트 컴프리헨션을 사용하세요.
col_amt =

# %%
# col_amt를 출력합니다.
col_amt

# %%
# merged에서 열이름이 col_amt인 원소를 선택하여 merged_amt에 할당합니다.
merged_amt =

# %%
# merged_amt를 출력합니다.
merged_amt

# %%
# merged의 열이름에서 'usd'를 포함하는 원소만 남겨 col_usd에 할당합니다.
# [힌트] 리스트 컴프리헨션을 사용하세요.
col_usd =

# %%
# col_usd를 출력합니다.
col_usd

# %%
# merged에서 열이름이 col_usd인 원소를 선택하여 merged_usd에 할당합니다.
merged_usd =

# %%
# merged_usd를 출력합니다.
merged_usd

# %%
# merged의 열이름에서 'avg'를 포함하는 원소만 남겨 col_avg에 할당합니다.
# [힌트] 리스트 컴프리헨션을 사용하세요.
col_avg =

# %%
# col_avg를 출력합니다.
col_avg

# %%
# merged에서 열이름이 col_avg인 원소를 선택하여 merged_avg에 할당합니다.
merged_avg =

# %%
# merged_avg를 출력합니다.
merged_avg

# %%
# merged_amt, merged_usd, merged_avg를 열 방향으로 결합하고 merged에 할당합니다.
# [힌트] pd.concat() 함수를 사용하세요.
# [주의] axis 매개변수의 기본값은 0(행)이므로 1(열)을 지정해야 합니다.
merged =

# %%
# merged를 출력합니다.
merged

# %%
# merged를 인덱스로 오름차순 정렬한 결과를 출력합니다.

# %%
# merged를 인덱스로 오름차순 정렬한 결과를 merged에 재할당합니다.
merged =

# %% [markdown]
# ### 외부 파일로 저장

# %%
# 현재 작업 경로를 확인합니다.

# %%
# 여러 객체를 하나의 압축 파일로 저장합니다.
# 파일명은 'Online_Mall.z'으로 지정하세요.
# [힌트] joblib.dump() 함수를 사용하세요.
# %time

# %%
# rawdat를 xlsx 파일로 저장합니다.
# [참고] 데이터프레임의 인덱스를 추가하지 않도록 설정합니다.
# %time

# %%
# merged를 xlsx 파일로 저장합니다.
# [참고] 데이터프레임의 인덱스를 추가도록 설정합니다.
# %time

# %%
# 작업 경로에 있는 폴더명과 파일명을 출력합니다.

# %% [markdown]
# ## End of Document
