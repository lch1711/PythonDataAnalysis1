# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 관련 라이브러리 호출

# %%
# 관련 라이브러리를 호출합니다.
import os
import joblib
import numpy as np
import pandas as pd

# %% [markdown]
# ### 작업 경로 확인 및 변경

# %%
# 현재 작업 경로를 확인합니다.
os.getcwd()

# %%
# data 폴더로 작업 경로를 변경합니다.
os.chdir(path = '../data')

# %%
# 현재 작업 경로에 있는 폴더명과 파일명을 출력합니다.
sorted(os.listdir())

# %% [markdown]
# ### 실습 데이터셋 준비

# %%
# z 파일을 읽고 price에 할당합니다.
price = joblib.load(filename = 'APT_Price_Seoul_2020_2022.z')

# %%
# price의 정보를 확인합니다.
price.info()

# %%
# price의 처음 5행을 출력합니다.
price.head()

# %% [markdown]
# ### 열 선택

# %%
# 열이름을 문자열 스칼라로 지정하면 시리즈로 반환합니다.
# [참고] 열이름을 리스트로 지정하면 데이터프레임으로 반환합니다.
price['지역코드']

# %%
# 2개 이상의 열을 선택하려면 반드시 리스트로 지정해야 합니다.(배열 인덱싱)
# [참고] 열이름 순서를 변경하면 위치를 바꿔서 반환합니다.
price[['아파트', '지역코드']]

# %%
# 슬라이스로 연속된 열을 선택하려면 loc 인덱서를 추가합니다.(슬라이싱)
# [주의] loc 인덱서를 생략하면 에러를 반환합니다.
price.loc[:, '거래일':'거래금액']

# %%
# 조건을 만족하는 열을 선택합니다.(불리언 인덱싱)
price.loc[:, price.dtypes == np.int64]

# %%
# 열이름에서 '거래'를 포함하는 열을 선택합니다.(불리언 인덱싱)
price.loc[:, price.columns.str.contains(pat = '거래')]

# %% [markdown]
# ### 열 삭제

# %%
# 삭제할 열이름을 drop() 함수의 columns 매개변수에 리스트로 지정합니다.
price.drop(columns = ['지역코드'])

# %%
# price의 처음 5행을 출력합니다. price는 여전히 지역코드를 포함하고 있습니다.
price.head()

# %%
# 열을 삭제하고 재할당하면 데이터프레임에서 해당 열을 삭제합니다.
price = price.drop(columns = ['지역코드'])
price.head()

# %% [markdown]
# ### 열이름 변경

# %%
# 일부 열이름을 변경한 결과를 출력합니다.
# [주의] columns 매개변수를 생략하면 안됩니다!
price.rename(columns = {'시도명': '시', '시군구': '구', '법정동': '동'})

# %%
# price의 열이름을 출력합니다.
price.columns

# %%
# 전체 열이름을 변경합니다.
# [주의] 데이터프레임의 열이름과 원소 개수가 같은 리스트를 지정해야 합니다.
price.columns = ['아파트', '시', '구', '동', '지번', '건축년도', 
                 '거래일', '전용면적', '층', '거래금액']
price.head()

# %% [markdown]
# ### 열별 자료형 변환

# %% [raw]
# # 시리즈의 원소 자료형을 변환합니다.
# # [참고] 거래금액 원소에 콤마가 있으므로 실수로 변환할 수 없습니다.
# price['거래금액'].astype(dtype = float)

# %%
# 거래금액 원소에 있는 콤마를 삭제하고 재할당합니다.
price['거래금액'] = price['거래금액'].str.replace(pat = ',', repl = '')

# %%
# 시리즈의 원소 자료형을 실수형으로 변환하고 재할당합니다.
price['거래금액'] = price['거래금액'].astype(dtype = float)
price.dtypes

# %%
# 데이터프레임의 열별로 자료형 변환 방법을 딕셔너리로 지정합니다.
price = price.astype(dtype = {'거래일': np.datetime64, '층': float})
price.dtypes

# %%
# 정수형으로 변환할 열이름으로 리스트를 생성합니다.
cols = ['층', '거래금액']

# %%
# 선택한 열의 자료형을 일괄 변환합니다.
price[cols] = price[cols].astype(dtype = int)
price.dtypes

# %% [markdown]
# ### [참고] 문자열을 날짜형으로 변환

# %%
# 날짜 기본형이 아닌 문자열 리스트로 시리즈를 생성합니다.
birth = pd.Series(data = ['2000년 1월 1일'])
birth

# %% [raw]
# # birth를 날짜형으로 변환하려고 하면 에러를 반환합니다.
# birth.astype(dtype = np.datetime64)

# %%
# to_datetime() 함수에 날짜 포맷을 지정하면 문자열을 날짜형으로 변환합니다.
birth = pd.to_datetime(arg = birth, format = '%Y년 %m월 %d일')

# %%
# birth의 첫 번째 원소를 선택합니다.
birth.iloc[0]

# %% [markdown]
# ### [참고] 날짜/시간 데이터 연산

# %%
# 현재 날짜/시간 데이터를 생성합니다.
today = pd.Timestamp.today()
today.timestamp()

# %%
# 태어나서 현재까지 살아온 기간을 dtGap에 할당합니다.
dtGap = today - birth.iloc[0]

# %%
# dtGap에서 경과일수를 출력합니다.
dtGap.days

# %% [markdown]
# ### [참고] 날짜/시간 분해 함수

# %%
# 거래일에서 년(year)을 정수형 시리즈로 반환합니다.
price['거래일'].dt.year

# %%
# 거래일에서 월(month)을 정수형 시리즈로 반환합니다.
price['거래일'].dt.month

# %%
# 거래일에서 일(day)을 정수형 시리즈로 반환합니다.
price['거래일'].dt.day

# %%
# 거래일에서 영문 요일을 문자형 시리즈로 반환합니다.
price['거래일'].dt.day_name()

# %%
# 거래일에서 한글 요일을 문자형 시리즈로 반환합니다.
price['거래일'].dt.day_name(locale = 'ko_KR')

# %%
# 거래일에서 요일을 문자형 시리즈로 반환합니다.(로케일에 따라 결과가 달라집니다.)
price['거래일'].dt.strftime(date_format = '%A')

# %% [markdown]
# ### 조건에 맞는 행 선택: 연속형 변수

# %%
# 거래금액이 120억 이상인 행을 선택하여 df1에 할당합니다.
df1 = price[price['거래금액'] >= 1200000]
df1

# %%
# 거래금액이 120억 미만이고 65층 이상인 행을 선택하여 df2에 할당합니다.
df2 = price[(price['거래금액'] < 1200000) & (price['층'] >= 65)]
df2

# %% [markdown]
# ### [참고] 시리즈의 비교 연산 함수

# %%
# 층이 65 초과면 True, 아니면 False인 부울형 시리즈를 반환합니다.
price['층'].gt(65).sum()

# %%
# 층이 65 이상이면 True, 아니면 False인 부울형 시리즈를 반환합니다.
price['층'].ge(65).sum()

# %%
# 층이 65 미만이면 True, 아니면 False인 부울형 시리즈를 반환합니다.
price['층'].lt(65).sum()

# %%
# 층이 65 이하이면 True, 아니면 False인 부울형 시리즈를 반환합니다.
price['층'].le(65).sum()

# %%
# 층이 65이면 True, 65가 아니면 False인 부울형 시리즈를 반환합니다.
price['층'].eq(65).sum()

# %%
# 층이 65가 아니면 True, 65이면 False인 부울형 시리즈를 반환합니다.
price['층'].ne(65).sum()

# %%
# 비교 연산 함수는 시리즈이므로 소괄호로 감싸지 않아도 됩니다.
price['거래금액'].lt(1200000) & price['층'].ge(65)

# %% [markdown]
# ### 조건에 맞는 행 선택: 범주형 변수

# %%
# 구가 '강남구'인 행을 선택합니다.
price[price['구'].eq('강남구')]

# %%
# 구가 '강남구' 또는 '서초구'인 행을 선택합니다.
price[price['구'].eq('강남구') | price['구'].eq('서초구')]

# %%
# isin() 함수는 시리즈 원소가 리스트에 있으면 True, 없으면 False로 반환합니다.
price[price['구'].isin(values = ['강남구', '서초구'])]

# %%
# str.contains() 함수는 원소에 패턴 포함 여부를 True 또는 False로 반환합니다.
price[price['구'].str.contains(pat = '강남|서초')]

# %% [markdown]
# ### [참고] 시리즈를 문자열로 처리하는 주요 함수

# %%
# 실습용 시리즈를 생성합니다.
addr = pd.Series(data = ['서울특별시 강남구', '경기도 성남시 분당구'])

# %%
# 문자열(원소)마다 지정한 패턴을 변경합니다.
addr.str.replace(pat = ' ', repl = '')

# %%
# 문자열(원소)을 지정한 패턴으로 분리한 결과를 데이터프레임으로 반환합니다.
addr.str.split(pat = ' ', expand = True)

# %%
# 문자열(원소)마다 지정한 패턴이 있으면 시작 인덱스를 반환합니다.
# [참고] 지정한 패턴이 없으면 -1을 반환합니다.
addr.str.find(sub = '시')

# %%
# 문자열(원소)을 지정한 인덱스로 자릅니다.
addr.str.slice(start = 0, stop = 2)

# %%
# 문자열(원소)마다 지정한 패턴에 해당하는 문자열을 추출합니다.
# [주의] 패턴을 소괄호로 감싸야 합니다.
addr.str.extract(pat = '([가-힣]+구)')

# %% [markdown]
# ### 행이름으로 행 삭제

# %%
# df1의 처음 5행을 출력합니다.
df1.head()

# %%
# df1의 인덱스를 출력합니다.
df1.index

# %%
# 삭제할 행이름을 drop() 함수의 index 매개변수에 리스트로 지정합니다.
# [주의] 행이름에 없는 값을 지정하면 에러를 반환합니다.
df1.drop(index = [126596, 131285])

# %%
# 인덱스를 슬라이싱한 코드로 행이름 리스트를 대신할 수 있습니다.
df1.drop(index = df1.index[0:2])

# %% [markdown]
# ### 행이름 초기화

# %%
# 행이름을 초기화한 결과를 출력합니다.
# [참고] 기존 행이름을 데이터프레임의 첫 번째 열로 추가합니다.
df1.reset_index()

# %%
# 행이름을 초기화하지만 기존 행이름을 열로 추가하지 않습니다.
df1.reset_index(drop = True)

# %%
# 특정 열을 인덱스로 지정합니다.
df1 = df1.set_index(keys = ['아파트'])
df1

# %%
# 행이름을 초기화하면서 기존 행이름을 열로 추가합니다.
df1 = df1.reset_index()
df1

# %% [markdown]
# ### 결측값 처리: 원본 데이터로 채워넣기

# %%
# 데이터프레임의 셀 값별 결측값 여부를 True/False로 반환합니다.
price.isna()

# %%
# 데이터프레임의 열별 결측값 개수를 계산합니다.
price.isna().sum()

# %%
# 지번이 결측값인 행을 선택합니다.
price[price['지번'].isna()]

# %%
# 지번이 결측인 아파트별로 원본 데이터를 찾아서 채워넣습니다.
price.loc[price['아파트'].eq('서초포레스타2단지'), '지번'] = '384'
price.loc[price['아파트'].eq('힐스테이트 서초 젠트리스'), '지번'] = '557'

# %% [markdown]
# ### 결측값 처리: 단순대체

# %%
# 데이터프레임의 열별 결측값 개수를 계산합니다.
price.isna().sum()

# %%
# 건축년도가 결측값인 행을 선택합니다.
price[price['건축년도'].isna()]

# %%
#  결측값인 행에서 결측값을 빈 문자열로 대체한 결과를 반환합니다.
price[price['건축년도'].isna()].fillna(value = '-')

# %% [markdown]
# ### [참고] 결측값을 이전 셀 값으로 채우기

# %%
# 현재 작업 경로에 있는 폴더명과 파일명을 출력합니다.
sorted(os.listdir())

# %%
# 법정동별 평균 거래금액 xlsx 파일을 읽고 데이터프레임을 생성합니다.
na = pd.read_excel(io = 'NA_Sample.xlsx')

# %%
# na를 출력합니다. 구분 열에 결측값이 많습니다.
# [참고] xlsx에서 병합한 셀은 처음 값만 제대로 읽고 나머지는 결측값으로 대체합니다.
na

# %%
# 결측값을 이전 셀 값으로 채웁니다.
# [참고] method 매개변수에 'bfill'을 지정하면 결측값을 이후 셀 값으로 채웁니다.
na.fillna(method = 'ffill')

# %% [markdown]
# ### 결측값 처리: 행 삭제

# %%
# 데이터프레임에서 결측값이 있는 모든 행을 삭제한 결과를 반환합니다.
price.dropna()

# %%
# 건축년도에서 결측값이 없는 행을 선택한 결과를 반환합니다.
price[~price['건축년도'].isna()]

# %%
# 건축년도에서 결측값이 아닌 행을 선택하고 price에 재할당합니다.
price = price[price['건축년도'].notna()]

# %%
# 건축년도를 정수형으로 변환합니다.
price['건축년도'] = price['건축년도'].astype(int)

# %% [markdown]
# ### 파생변수 생성 : 연속형 변수

# %%
# 거래금액을 전용면적으로 나누고 3.3을 곱한 평당금액을 생성합니다.
price['평당금액'] = price['거래금액'] / price['전용면적'] * 3.3
price.head()

# %%
# pandas 옵션에서 실수를 출력하는 소수점 자리수를 3으로 설정합니다.
pd.options.display.precision = 3

# %%
# 거래금액을 10000으로 나누어 거래금액의 단위를 만원에서 억원으로 변경합니다.
price['거래금액'] = price['거래금액'] / 10000
price.head()

# %%
# 정수형 변수인 거래년도를 생성합니다.
price['거래년도'] = price['거래일'].dt.year

# %%
# 거래년도에서 건축년도를 뺀 경과년수를 생성합니다.
price['경과년수'] = price['거래년도'] - price['건축년도']
price.head()

# %%
# 문자형 변수인 거래월을 생성합니다.
price['거래월'] = price['거래일'].dt.strftime(date_format = '%m월')

# %% [markdown]
# ### 파생변수 생성 : 범주형 변수

# %%
# 평당금액이 5000 이상이면 True, 아니면 False인 원소를 갖는 locs를 생성합니다.
# [참고] locs는 부울형 시리즈입니다.
locs = price['평당금액'].ge(5000)
locs.head()

# %%
# 평당금액을 '5천 이상', '5천 미만'으로 구분한 금액구간을 생성합니다.
# [참고] np.where() 함수는 조건이 True일 때 두 번째 인수, False일 때 세 번째 인수를 반환합니다.
price['금액구간'] = np.where(locs, '5천 이상', '5천 미만')
price.head()

# %% [markdown]
# ### [참고] 구간화 함수

# %%
# 연속형 변수를 세 개 이상으로 분리할 때 np.where() 함수를 중첩합니다.
np.where(price['평당금액'].ge(10000), 
         '1억 이상', 
         np.where(price['평당금액'].ge(5000), 
                  '5천 이상', 
                  '5천 미만'))

# %%
# 연속형 변수를 세 개 이상으로 분리할 때 np.select() 함수를 사용합니다.
np.select(condlist = [price['평당금액'].ge(10000),
                      price['평당금액'].ge(5000),
                      price['평당금액'].lt(5000)], 
          choicelist = ['1억 이상', '5천 이상', '5천 미만'])

# %% [markdown]
# ### 파생변수 생성: 문자형 변수 결합

# %%
# 여러 문자형 변수를 + 연산자로 결합합니다.
price['주소'] = price['시'] + ' ' + price['구'] + ' ' + \
                price['동'] + ' ' + price['지번']
price.head()

# %%
# 결합할 문자형 열이름으로 리스트를 생성합니다.
cols = ['시', '구', '동', '지번']

# %%
# 데이터프레임의 행(시리즈)별로 문자열을 결합하는 함수를 반복 실행합니다.
price[cols].apply(func = lambda x: ' '.join(x), axis = 1)

# %% [markdown]
# ### [참고] 같은 함수 반복 실행 실습

# %%
# 아파트(시리즈)의 원소(문자열)별 글자수를 반환합니다.
price['아파트'].map(arg = len)

# %%
# 데이터프레임의 열(시리즈)별 원소 개수를 반환합니다.
price[cols].apply(func = len, axis = 0)

# %%
# 데이터프레임의 행(시리즈)별 원소 개수를 반환합니다.
price[cols].apply(func = len, axis = 1)

# %%
# 데이터프레임의 셀 값(문자열)별 글자수를 반환합니다.
price[cols].applymap(func = len)

# %% [markdown]
# ### 데이터프레임 정렬

# %%
# 층을 오름차순 정렬합니다.
# [참고] ascending 매개변수에 전달하는 인수의 기본값은 True입니다.
price['층'].sort_values()

# %%
# 층을 내림차순 정렬합니다.
price['층'].sort_values(ascending = False)

# %%
# price를 층으로 오름차순 정렬합니다.
price.sort_values(by = ['층'])

# %%
# price를 층으로 내림차순 정렬합니다.
price.sort_values(by = ['층'], ascending = False)

# %%
# price를 층과 거래금액으로 내림차순 정렬합니다.
price.sort_values(by = ['층', '거래금액'], ascending = False)

# %%
# price를 층은 내림차순, 거래금액은 오름차순 정렬합니다.
price.sort_values(by = ['층', '거래금액'], ascending = [False, True])

# %% [markdown]
# ### 집계함수로 데이터 요약

# %%
# 거래금액에서 결측값을 제외한 빈도수를 반환합니다.
price['거래금액'].count()

# %%
# 거래금액의 합계를 반환합니다.
price['거래금액'].sum()

# %%
# 거래금액의 평균을 반환합니다.
price['거래금액'].mean()

# %%
# 거래금액의 표준편차를 반환합니다.
price['거래금액'].std()

# %%
# 거래금액의 최솟값을 반환합니다.
price['거래금액'].min()

# %%
# 거래금액의 최댓값을 반환합니다.
price['거래금액'].max()

# %% [markdown]
# ### 범주별 집계함수로 데이터 요약

# %%
# 거래년도별 거래금액에서 결측값을 제외한 빈도수를 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].count()

# %%
# 거래년도별 거래금액의 합계를 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].sum()

# %%
# 거래년도별 거래금액의 평균을 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].mean()

# %%
# 거래년도별 거래금액의 표준편차를 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].std()

# %%
# 거래년도별 거래금액의 최솟값을 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].min()

# %%
# 거래년도별 거래금액의 최댓값을 반환합니다.
price.groupby(by = ['거래년도'])['거래금액'].max()

# %% [markdown]
# ### 범주형/이산형 변수의 빈도수/상대도수 확인

# %%
# 구에서 중복을 제거한 원소를 반환합니다.
price['구'].unique()

# %%
# 구에서 중복을 제거한 원소 개수를 반환합니다.
price['구'].nunique()

# %%
# 구별 빈도수를 내림차순 정렬한 결과를 반환합니다.
price['구'].value_counts()

# %%
# 구별 빈도수를 오름차순 정렬한 결과를 반환합니다.
price['구'].value_counts(ascending = True)

# %%
# 구별 빈도수를 시리즈 인덱스로 오름차순 정렬한 결과를 반환합니다.
price['구'].value_counts().sort_index()

# %%
# 구별 상대도수를 내림차순 정렬한 결과를 반환합니다.
price['구'].value_counts(normalize = True)

# %% [markdown]
# ### Long type 데이터프레임 생성

# %%
# 두 범주형 변수의 빈도수로 Long type 데이터프레임을 생성합니다.
elong = price.groupby(by = ['구', '금액구간'])[['거래금액']].count()
elong.head(n = 10)

# %%
# elong의 행이름을 초기화하고 기존 행이름을 열로 추가합니다.
elong = elong.reset_index()
elong.head(n = 10)

# %%
# elong의 일부 열이름을 변경합니다.
elong = elong.rename(columns = {'거래금액': '매매건수'})

# %% [markdown]
# ### Long type을 Wide type으로 변환

# %%
# Long type을 Wide type으로 변환합니다.
widen = elong.pivot(index = '구', 
                    columns = '금액구간', 
                    values = '매매건수')
widen.head()

# %%
# widen의 행이름을 출력합니다.
# [참고] 인덱스(행이름)에 name 속성이 있고, 속성값은 '구'입니다.
widen.index

# %%
# 인덱스(행이름)의 name을 출력합니다.
widen.index.name

# %% [markdown]
# ### widen 행이름 초기화

# %%
# widen의 행이름을 초기화하고 기존 행이름을 열로 추가합니다.
widen = widen.reset_index()
widen.head()

# %%
# widen의 열이름을 출력합니다.
# [참고] 열이름에 name 속성이 있고, 속성값은 '금액구간'입니다.
widen.columns

# %%
# 열이름의 name을 출력합니다.
widen.columns.name

# %%
# 열이름의 name에 None을 할당하여 열이름의 name을 제거합니다.
widen.columns.name = None
widen.head()

# %% [markdown]
# ### Wide type을 Long type으로 변환

# %%
# Wide type을 Long type으로 변환합니다.
widen.melt(id_vars = '구', 
           value_vars = ['5천 미만', '5천 이상'], 
           var_name = '금액구분',
           value_name = '거래건수') \
     .sort_values(by = ['구', '금액구분']) \
     .reset_index(drop = True) \
     .head()

# %% [markdown]
# ### 피벗 테이블 생성

# %%
# 두 범주형 변수로 연속형 변수를 요약한 피벗 테이블을 생성합니다.
pd.pivot_table(data = price, 
               values = '거래금액', 
               index = ['구', '동'], 
               columns = '금액구간', 
               aggfunc = np.mean, 
               dropna = True)

# %% [markdown]
# ### 교차 테이블 생성

# %%
# 두 범주형 변수의 빈도수/상대도수를 원소로 갖는 교차 테이블을 생성합니다.
pd.crosstab(index = [price['구'], price['동']],
            columns = price['금액구간'], 
            normalize = 'index',
            margins = True, 
            margins_name = '합계', 
            dropna = True)

# %% [markdown]
# ### 데이터프레임 결합

# %%
# 두 데이터프레임의 열이름이 순서까지 정확하게 같은지 확인합니다.
# [참고] 순서만 달라도 False를 반환합니다.
df1.columns.equals(other = df2.columns)

# %%
# 열이름이 같은 두 데이터프레임을 행(세로) 방향으로 결합합니다.
# [참고] 두 데이터프레임의 기존 행이름을 유지합니다.
pd.concat(objs = [df1, df2])

# %%
# 두 데이터프레임을 세로로 결합하고 행이름을 초기화합니다.
pd.concat(objs = [df1, df2], ignore_index = True)

# %%
# df2의 일부 열이름을 변경합니다.
df2 = df2.rename(columns = {'아파트': '아파트명'})

# %%
# 열이름이 다른 두 데이터프레임을 행(세로) 방향으로 결합합니다.
pd.concat(objs = [df1, df2], ignore_index = True)

# %% [markdown]
# ### 병합 데이터셋 준비

# %%
# 현재 작업 경로에 있는 폴더명과 파일명을 출력합니다.
sorted(os.listdir())

# %%
# 상세정보 xlsx 파일을 읽고 데이터프레임을 생성합니다.
detail = pd.read_excel(io = 'APT_Detail_Seoul_2022.xlsx')

# %%
# detail의 정보를 확인합니다.
detail.info()

# %%
# detail의 처음 5행을 출력합니다.
detail.head()

# %% [markdown]
# ### 외래키 확인

# %%
# 두 데이터프레임의 외래키에서 일치하는 원소 개수를 확인합니다.
len(set(price['아파트']) & set(detail['아파트명']))

# %%
# 두 데이터프레임의 외래키에서 일치하는 원소 개수를 확인합니다.
len(set(price['주소']) & set(detail['지번주소']))

# %%
# price의 처음 5행을 출력합니다.
# [참고] price의 주소가 '서울특별시'로 시작합니다.
price.head()

# %%
# detail의 처음 5행을 출력합니다.
# [참고] detail의 지번주소는 '서울시'로 시작합니다.
detail.head()

# %% [markdown]
# ### 외래키 전처리

# %%
# price의 주소에서 '특별'을 삭제합니다.
price['주소'] = price['주소'].str.replace(pat = '특별', repl = '')
price['주소'].head()

# %%
# 외래키에서 일치하는 원소 개수를 다시 확인합니다.
len(set(price['주소']) & set(detail['지번주소']))

# %% [markdown]
# ### [참고] 비복원추출 및 시드 고정

# %%
# 로또 번호를 출력합니다. 마음에 들 때까지 여러 번 반복해보세요.
np.random.choice(a = range(1, 46), size = 6, replace = False)

# %%
# 시드를 고정하면 항상 재현 가능한 결과를 얻습니다.
np.random.seed(seed = 1)
np.random.choice(a = range(1, 46), size = 6, replace = False)

# %% [markdown]
# ### [참고] 복원추출

# %%
# 시드를 고정합니다.
np.random.seed(seed = 2)

# %%
# 1~5의 정수에서 3개를 복원추출합니다.
nums = np.random.choice(a = range(1, 6), size = 5)

# %%
# nums를 시리즈로 변환합니다.
nums = pd.Series(data = nums)
nums

# %% [markdown]
# ### [참고] 중복 원소 확인 함수

# %%
# 순방향으로 원소 중복 여부를 True 또는 False로 반환합니다.
nums.duplicated()

# %%
# 역방향으로 원소 중복 여부를 True 또는 False로 반환합니다.
nums.duplicated(keep = 'last')

# %%
# 모든 중복 원소를 True로 반환합니다.(탐색 방향과 상관 없음)
nums.duplicated(keep = False)

# %%
# 중복 원소 중 맨 처음 원소만 선택합니다.
nums[nums.duplicated()]

# %%
# 중복 원소 중 맨 마지막 원소만 선택합니다.
nums[nums.duplicated(keep = 'last')]

# %%
# 중복 원소를 모두 선택합니다.
nums[nums.duplicated(keep = False)]

# %% [markdown]
# ### 데이터프레임 중복 확인 및 제거

# %%
# detail의 지번주소가 중복이면 True, 아니면 False인 시리즈를 생성합니다.
dup = detail['지번주소'].duplicated(keep = False)

# %%
# detail에서 dup이 True인 행을 선택하고 지번주소로 오름차순 정렬합니다.
detail[dup].sort_values(by = ['지번주소'])

# %%
# detail의 지번주소에서 순방향으로 중복인 행을 제거하고 detail에 재할당합니다.
# [참고] ~ 연산자는 진리값을 반전합니다.
detail = detail[~detail['지번주소'].duplicated()]

# %%
# detail의 행 개수를 확인합니다. 행 개수가 감소했습니다.(9668 -> 9640)
detail.shape[0]

# %% [markdown]
# ### 데이터프레임 병합

# %%
# 두 데이터프레임으로 내부 병합을 실행합니다.
pd.merge(left = price, 
         right = detail, 
         how = 'inner', 
         left_on = '주소', 
         right_on = '지번주소')

# %%
# detail의 외래키 이름을 '주소'로 변경합니다.
detail = detail.rename(columns = {'지번주소': '주소'})

# %%
# price와 detail에서 일치하는 열이름을 확인합니다.
set(price.columns) & set(detail.columns)

# %%
# 외래키 이름이 같으면 on 매개변수를 사용합니다.
apt = pd.merge(left = price, right = detail, how = 'inner', on = '주소')

# %%
# apt의 정보를 확인합니다.
apt.info()

# %% [markdown]
# ### 외부 파일로 저장

# %%
# apt에서 불필요한 일부 열을 삭제합니다.
apt = apt.drop(columns = ['주소', '아파트ID', '아파트명'])

# %%
# apt를 xlsx 파일로 저장합니다.
# %time apt.to_excel(excel_writer = 'APT_Merged_Seoul_2022.xlsx', index = False)

# %%
# apt를 csv 파일로 저장합니다.
# %time apt.to_csv(path_or_buf = 'APT_Merged_Seoul_2022.csv', index = False)

# %%
# apt를 z 파일로 저장합니다.
# %time joblib.dump(value = apt, filename = 'APT_Merged_Seoul_2022.z')

# %% [markdown]
# ## End of Document
