# %%
import os
import chardet
import numpy as np
import pandas as pd
import joblib

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hdsce\\Documents\\PythonDataAnalysis1\\live'

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['App_Usage.csv',
#  'APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged.csv',
#  'APT_Merged.xlsx',
#  'APT_Prep.csv',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'APT_Price_Seoul_Copy.xlsx',
#  'NA_Sample.xlsx',
#  'Online_Mall.csv',
#  'test.xlsx']

# %%
fileName = 'APT_Prep.csv'

# %%
with open(file = fileName, mode = 'rb') as file:
    text = file.read()

# %%
text[:100]
# Out:
# b'\xec\x95\x84\xed\x8c\x8c\xed\x8a\xb8,\xec\x8b\x9c,\xea\xb5\xac,\xeb\x8f\x99,\xec\xa7\x80\xeb\xb2\x88,\xea\xb1\xb4\xec\xb6\x95\xeb\x85\x84\xeb\x8f\x84,\xea\xb1\xb0\xeb\x9e\x98\xec\x9d\xbc,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81,\xec\xb8\xb5,\xea\xb1\xb0\xeb\x9e\x98\xea\xb8\x88\xec\x95\xa1\r\n\xec\x8b\xa0\xeb\x8f\x99\xec\x95\x84\xeb\xb8\x94\xeb\xa3\xa8\xec\x95'

# %%
chardet.detect(text)
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}

# %%
price = pd.read_csv(fileName, encoding = 'UTF-8', parse_dates = ['거래일'])

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139917 entries, 0 to 139916
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     139917 non-null  object
#  1   시       139917 non-null  object
#  2   구       139917 non-null  object
#  3   동       139917 non-null  object
#  4   지번      139917 non-null  object
#  5   건축년도    139917 non-null  int64
#  6   거래일     139917 non-null  datetime64[ns]
#  7   전용면적    139917 non-null  float64
#  8   층       139917 non-null  int64
#  9   거래금액    139917 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 10.7+ MB

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#      거래금액
# 0  100000
# 1  162000
# 2   88000
# 3  130000
# 4  149000

# %%
price['평당금액'] = price['거래금액'] / price['전용면적'] * 3.3

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#      거래금액         평당금액
# 0  100000  2947.218005
# 1  162000  3273.128023
# 2   88000  2642.161769
# 3  130000  2206.449622
# 4  149000  3320.278209

# %%
price['평당금액'].round(3)
# Out:
# 0         2947.218
# 1         3273.128
# 2         2642.162
# 3         2206.450
# 4         3320.278
#             ...
# 139912    2938.508
# 139913    4005.575
# 139914    4260.563
# 139915    2298.248
# 139916    3025.504
# Name: 평당금액, Length: 139917, dtype: float64

# %%
pd.options.display.precision = 3

# %%
price['평당금액']
# Out:
# 0         2947.218
# 1         3273.128
# 2         2642.162
# 3         2206.450
# 4         3320.278
#             ...
# 139912    2938.508
# 139913    4005.575
# 139914    4260.563
# 139915    2298.248
# 139916    3025.504
# Name: 평당금액, Length: 139917, dtype: float64

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
#
#      거래금액      평당금액
# 0  100000  2947.218
# 1  162000  3273.128
# 2   88000  2642.162
# 3  130000  2206.450
# 4  149000  3320.278

# %%
price['거래금액'] = price['거래금액'] / 10000

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#        평당금액
# 0  2947.218
# 1  3273.128
# 2  2642.162
# 3  2206.450
# 4  3320.278

# %%
pd.reset_option('display.precision')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액
# 0  2947.218005
# 1  3273.128023
# 2  2642.161769
# 3  2206.449622
# 4  3320.278209

# %%
price['거래년도'] = price['거래일'].dt.year

# %%
price['경과년수'] = price['거래년도'] - price['건축년도']

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액  거래년도  경과년수
# 0  2947.218005  2020    13
# 1  3273.128023  2020    12
# 2  2642.161769  2020    26
# 3  2206.449622  2020    16
# 4  3320.278209  2020    17

# %%
price['거래월'] = price['거래일'].dt.strftime('%m월')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액  거래년도  경과년수  거래월
# 0  2947.218005  2020    13  01월
# 1  3273.128023  2020    12  01월
# 2  2642.161769  2020    26  01월
# 3  2206.449622  2020    16  01월
# 4  3320.278209  2020    17  01월

# %%
locs = price['평당금액'].ge(5000)
locs
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139912    False
# 139913    False
# 139914    False
# 139915    False
# 139916    False
# Name: 평당금액, Length: 139917, dtype: bool

# %%
np.where(locs)
# Out:
# (array([    52,     53,    148, ..., 139900, 139903, 139905], dtype=int64),)

# %%
price['금액구간'] = np.where(locs, '5천 이상', '5천 미만')

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액  거래년도  경과년수  거래월   금액구간
# 0  2947.218005  2020    13  01월  5천 미만
# 1  3273.128023  2020    12  01월  5천 미만
# 2  2642.161769  2020    26  01월  5천 미만
# 3  2206.449622  2020    16  01월  5천 미만
# 4  3320.278209  2020    17  01월  5천 미만

# %%
imsi = price.drop(columns = ['금액구간']).copy()

# %%
imsi.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액  거래년도  경과년수  거래월
# 0  2947.218005  2020    13  01월
# 1  3273.128023  2020    12  01월
# 2  2642.161769  2020    26  01월
# 3  2206.449622  2020    16  01월
# 4  3320.278209  2020    17  01월

# %%
# imsi에 '금액구간' 열이 없지만 아래 코드를 통해 새로 추가됩니다.
imsi.loc[imsi['평당금액'].ge(5000), '금액구간'] = '5천 이상'
# Out:
#                  아파트      시    구    동      지번  건축년도        거래일      전용면적   층  \
# 139897        고덕그라시움  서울특별시  강동구  고덕동     693  2019 2022-12-20   59.7850  20
# 139898        고덕그라시움  서울특별시  강동구  고덕동     693  2019 2022-12-24   84.0460  33
# 139899          고덕자이  서울특별시  강동구  상일동     521  2021 2022-12-02   59.9398  23
# 139900        고덕아르테온  서울특별시  강동구  상일동     519  2020 2022-12-02   59.9800  10
# 139901     고덕리엔파크3단지  서울특별시  강동구  상일동     490  2011 2022-12-03   84.9800   8
# 139902    고덕센트럴IPARK  서울특별시  강동구  상일동     513  2019 2022-12-04   84.9700   5
# 139903        고덕아르테온  서울특별시  강동구  상일동     519  2020 2022-12-06   84.9500  15
# 139904    고덕센트럴IPARK  서울특별시  강동구  상일동     513  2019 2022-12-17   74.8800   9
# 139905        고덕아르테온  서울특별시  강동구  상일동     519  2020 2022-12-17   59.9800  17
# 139906  청광플러스원(큐브1차)  서울특별시  강동구   길동   387-5  2012 2022-12-16   17.0750   7
# 139907  청광플러스원(큐브1차)  서울특별시  강동구   길동   387-5  2012 2022-12-16   16.6850   9
# ...

# %%
imsi.loc[imsi['평당금액'].lt(5000), '금액구간'] = '5천 미만'

# %%
price['주소'] = price['시'] + ' ' + price['구'] + ' ' \
                + price['동'] + ' ' + price['지번']

# %%
price.head()
# Out:
#               아파트      시    구    동      지번  건축년도        거래일    전용면적   층  거래금액  \
# 0     신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6  10.0
# 1  광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2  16.2
# 2           세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11   8.8
# 3            킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4  13.0
# 4        경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8  14.9
#
#           평당금액  거래년도  경과년수  거래월   금액구간                    주소
# 0  2947.218005  2020    13  01월  5천 미만     서울특별시 종로구 필운동 254
# 1  3273.128023  2020    12  01월  5천 미만     서울특별시 종로구 사직동 9-1
# 2  2642.161769  2020    26  01월  5천 미만     서울특별시 종로구 내수동 167
# 3  2206.449622  2020    16  01월  5천 미만  서울특별시 종로구 내수동 110-15
# 4  3320.278209  2020    17  01월  5천 미만      서울특별시 종로구 내수동 95

# %%
sen = '서울특별시 강남구 역삼동 1'

# %%
strs = sen.split()

# %%
' '.join(strs)
# Out:
# '서울특별시 강남구 역삼동 1'

# %%
lambda x: ' '.join(x)
# Out:
# '서울특별시 강남구 역삼동 1'

# %%
cols = ['시', '구', '동', '지번']
price[cols]
# Out:
#             시    구    동      지번
# 0       서울특별시  종로구  필운동     254
# 1       서울특별시  종로구  사직동     9-1
# 2       서울특별시  종로구  내수동     167
# 3       서울특별시  종로구  내수동  110-15
# 4       서울특별시  종로구  내수동      95
# ...       ...  ...  ...     ...
# 139912  서울특별시  강동구  암사동  493-14
# 139913  서울특별시  강동구  암사동   414-2
# 139914  서울특별시  강동구  암사동     509
# 139915  서울특별시  강동구  성내동   452-2
# 139916  서울특별시  강동구  강일동     114
#
# [139917 rows x 4 columns]

# %%
price[cols].apply(func = lambda x: ' '.join(x), axis = 1)
# Out:
# 0            서울특별시 종로구 필운동 254
# 1            서울특별시 종로구 사직동 9-1
# 2            서울특별시 종로구 내수동 167
# 3         서울특별시 종로구 내수동 110-15
# 4             서울특별시 종로구 내수동 95
#                   ...
# 139912    서울특별시 강동구 암사동 493-14
# 139913     서울특별시 강동구 암사동 414-2
# 139914       서울특별시 강동구 암사동 509
# 139915     서울특별시 강동구 성내동 452-2
# 139916       서울특별시 강동구 강일동 114
# Length: 139917, dtype: object

# %%
price['아파트']
# Out:
# 0            신동아블루아광화문의꿈
# 1         광화문스페이스본(106동)
# 2                  세종로대우
# 3                   킹스매너
# 4               경희궁파크팰리스
#                ...
# 139912             중앙하이츠
# 139913           롯데캐슬퍼스트
# 139914           선사현대아파트
# 139915           파크뷰진도맨션
# 139916         강동리버스트4단지
# Name: 아파트, Length: 139917, dtype: object

# %%
price['아파트'].map(len)
# Out:
# 0         11
# 1         14
# 2          5
# 3          4
# 4          8
#           ..
# 139912     5
# 139913     7
# 139914     7
# 139915     7
# 139916     9
# Name: 아파트, Length: 139917, dtype: int64

# %%
price[cols]
# Out:
#             시    구    동      지번
# 0       서울특별시  종로구  필운동     254
# 1       서울특별시  종로구  사직동     9-1
# 2       서울특별시  종로구  내수동     167
# 3       서울특별시  종로구  내수동  110-15
# 4       서울특별시  종로구  내수동      95
# ...       ...  ...  ...     ...
# 139912  서울특별시  강동구  암사동  493-14
# 139913  서울특별시  강동구  암사동   414-2
# 139914  서울특별시  강동구  암사동     509
# 139915  서울특별시  강동구  성내동   452-2
# 139916  서울특별시  강동구  강일동     114
#
# [139917 rows x 4 columns]

# %%
price[cols].apply(len, axis = 1)
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 139912    4
# 139913    4
# 139914    4
# 139915    4
# 139916    4
# Length: 139917, dtype: int64

# %%
price[cols].apply(len, axis = 0)
# Out:
# 시     139917
# 구     139917
# 동     139917
# 지번    139917
# dtype: int64

# %%
price[cols].applymap(len)
# Out:
#         시  구  동  지번
# 0       5  3  3   3
# 1       5  3  3   3
# 2       5  3  3   3
# 3       5  3  3   6
# 4       5  3  3   2
# ...    .. .. ..  ..
# 139912  5  3  3   6
# 139913  5  3  3   5
# 139914  5  3  3   3
# 139915  5  3  3   5
# 139916  5  3  3   3
#
# [139917 rows x 4 columns]

# %%
price['층'].sort_values()
# Out:
# 17278     -3
# 49742     -3
# 31734     -2
# 49607     -2
# 29747     -2
#           ..
# 122507    64
# 69573     66
# 110650    66
# 50867     66
# 55000     67
# Name: 층, Length: 139917, dtype: int64

# %%
price['층'].sort_values(ascending=False)
# Out:
# 55000     67
# 110650    66
# 50867     66
# 69573     66
# 137285    64
#           ..
# 49607     -2
# 45769     -2
# 52683     -2
# 17278     -3
# 49742     -3
# Name: 층, Length: 139917, dtype: int64

# %%
price.sort_values(by = ['층'])
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일      전용면적  \
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.5100
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.5100
# 31734            롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27   59.8946
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.9900
# 29747     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-06-30   76.6600
# ...                   ...    ...  ...  ...     ...   ...        ...       ...
# 122507             타워팰리스1  서울특별시  강남구  도곡동     467  2002 2021-09-30  222.4800
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.6220
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.9670
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.0500
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.7400
#
# ...

# %%
price.sort_values(by = ['층'], ascending = False)
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적  \
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 137285             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2022-08-29  244.224
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# 45769     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30  107.990
# 52683           천왕연지타운2단지  서울특별시  구로구  천왕동     281  2014 2020-07-02   84.780
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
#
# ...

# %%
price.sort_values(by = ['층', '거래금액'], ascending = False)
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일      전용면적  \
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.7400
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.9670
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.6220
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.0500
# 137285             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2022-08-29  244.2240
# ...                   ...    ...  ...  ...     ...   ...        ...       ...
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.9900
# 31734            롯데캐슬골든힐스  서울특별시  성북구  길음동  1287-1  2019 2020-06-27   59.8946
# 52683           천왕연지타운2단지  서울특별시  구로구  천왕동     281  2014 2020-07-02   84.7800
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.5100
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.5100
#
# ...

# %%
price.sort_values(by = ['층', '거래금액'], ascending = [False, True])
# Out:
#                       아파트      시    구    동      지번  건축년도        거래일     전용면적  \
# 55000              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-07-25  235.740
# 50867             현대하이페리온  서울특별시  양천구   목동     916  2003 2020-07-03  154.050
# 69573              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2020-10-27  185.622
# 110650             타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-06-24  214.967
# 93843              타워팰리스3  서울특별시  강남구  도곡동  467-29  2004 2021-02-10  214.967
# ...                   ...    ...  ...  ...     ...   ...        ...      ...
# 49607   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-01  101.990
# 29747     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-06-30   76.660
# 45769     옥수파크힐스101동~116동  서울특별시  성동구  옥수동     528  2016 2020-07-30  107.990
# 17278   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-03-20  134.510
# 49742   은평뉴타운우물골(두산위브7단지)  서울특별시  은평구  진관동      84  2010 2020-07-23  134.510
#
# ...

# %%
price['거래금액'].count()
# Out:
# 139917

# %%
price['거래금액'].sum()
# Out:
# 1277873.9268999998

# %%
price['거래금액'].mean()
# Out:
# 9.133085521416268

# %%
price['거래금액'].std()
# Out:
# 6.747949076315124

# %%
price['거래금액'].min()
# Out:
# 0.6

# %%
price['거래금액'].max()
# Out:
# 145.0

# %%
price.groupby(by = ['거래년도'])['거래금액'].count()
# Out:
# 거래년도
# 2020    84294
# 2021    43420
# 2022    12203
# Name: 거래금액, dtype: int64

# %%
price.groupby(by = ['거래년도'])['거래금액'].sum()
# Out:
# 거래년도
# 2020    713033.1645
# 2021    445931.3192
# 2022    118909.4432
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].mean()
# Out:
# 거래년도
# 2020     8.458884
# 2021    10.270182
# 2022     9.744280
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].std()
# Out:
# 거래년도
# 2020    5.683750
# 2021    7.510029
# 2022    9.495091
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].min()
# Out:
# 거래년도
# 2020    0.60
# 2021    0.66
# 2022    0.67
# Name: 거래금액, dtype: float64

# %%
price.groupby(by = ['거래년도'])['거래금액'].max()
# Out:
# 거래년도
# 2020     77.5
# 2021    120.0
# 2022    145.0
# Name: 거래금액, dtype: float64

# %%
pvt = pd.pivot_table(
    data = price, 
    values = '거래금액', 
    index = '거래년도', 
    aggfunc = [np.size, np.sum, np.mean, np.std, np.min, np.max]
)
pvt
# Out:
#        size         sum    mean    std  amin   amax
#        거래금액        거래금액    거래금액   거래금액  거래금액   거래금액
# 거래년도
# 2020  84294  713033.164   8.459  5.684  0.60   77.5
# 2021  43420  445931.319  10.270  7.510  0.66  120.0
# 2022  12203  118909.443   9.744  9.495  0.67  145.0

# %%
pvt.columns
# Out:
# MultiIndex([('size', '거래금액'),
#             ( 'sum', '거래금액'),
#             ('mean', '거래금액'),
#             ( 'std', '거래금액'),
#             ('amin', '거래금액'),
#             ('amax', '거래금액')],
#            )

# %%
pvt[('size', '거래금액(원)')] = [f'{i:,}원' for i in pvt[('size', '거래금액')]]

# %%
pvt
# Out:
#        size         sum    mean    std  amin   amax     size
#        거래금액        거래금액    거래금액   거래금액  거래금액   거래금액  거래금액(원)
# 거래년도
# 2020  84294  713033.164   8.459  5.684  0.60   77.5  84,294원
# 2021  43420  445931.319  10.270  7.510  0.66  120.0  43,420원
# 2022  12203  118909.443   9.744  9.495  0.67  145.0  12,203원

# %%
pd.options.display.precision = 3

# %%
pd.pivot_table(
    data = price, 
    values = '거래금액', 
    index = ['구', '동'], 
    columns = '거래년도', 
    aggfunc = [np.size, np.mean, np.std]
)
# Out:
#           size                  mean                    std
# 거래년도      2020   2021   2022    2020    2021    2022   2020    2021    2022
# 구   동
# 강남구 개포동  440.0  260.0   62.0  17.807  21.087  21.830  6.250   7.559  10.046
#     논현동  177.0  164.0   74.0  11.497  12.426  12.273  6.610   8.817   9.091
#     대치동  386.0  249.0  106.0  22.370  23.628  22.713  9.285  11.964  14.554
#     도곡동  569.0  366.0  140.0  21.058  25.029  27.188  8.701  12.027  14.875
#     삼성동  303.0  186.0   68.0  15.866  19.331  25.452  9.327  13.286  17.519
# ...        ...    ...    ...     ...     ...     ...    ...     ...     ...
# 중랑구 면목동  692.0  390.0   94.0   4.981   6.421   5.337  1.820   2.737   3.410
#     묵동   456.0  249.0   76.0   5.910   7.132   5.221  2.128   2.811   2.978
#     상봉동  433.0  211.0  226.0   5.369   7.195   4.348  2.467   3.257   2.740
#     신내동  913.0  539.0   81.0   4.884   6.270   6.086  1.496   1.606   1.857
# ...

# %%
price['구'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
price['구'].nunique()
# Out:
# 25

# %%
price['구'].value_counts()
# Out:
# 노원구     13909
# 강서구      9322
# 구로구      8491
# 송파구      7432
# 성북구      7386
# 도봉구      6876
# 강동구      6801
# 강남구      6723
# 서초구      6194
# 영등포구     5998
# 양천구      5793
# 은평구      5724
# 동대문구     5496
# 중랑구      5089
# 동작구      5031
# 성동구      4920
# 마포구      4849
# 관악구      4604
# 서대문구     4558
# 강북구      3379
# 금천구      3093
# 용산구      2685
# 광진구      2310
# 중구       1835
# 종로구      1419
# Name: 구, dtype: int64

# %%
price['구'].value_counts(ascending = True)
# Out:
# 종로구      1419
# 중구       1835
# 광진구      2310
# 용산구      2685
# 금천구      3093
# 강북구      3379
# 서대문구     4558
# 관악구      4604
# 마포구      4849
# 성동구      4920
# 동작구      5031
# 중랑구      5089
# 동대문구     5496
# 은평구      5724
# 양천구      5793
# 영등포구     5998
# 서초구      6194
# 강남구      6723
# 강동구      6801
# 도봉구      6876
# 성북구      7386
# 송파구      7432
# 구로구      8491
# 강서구      9322
# 노원구     13909
# Name: 구, dtype: int64

# %%
price['구'].value_counts().sort_index()
# Out:
# 강남구      6723
# 강동구      6801
# 강북구      3379
# 강서구      9322
# 관악구      4604
# 광진구      2310
# 구로구      8491
# 금천구      3093
# 노원구     13909
# 도봉구      6876
# 동대문구     5496
# 동작구      5031
# 마포구      4849
# 서대문구     4558
# 서초구      6194
# 성동구      4920
# 성북구      7386
# 송파구      7432
# 양천구      5793
# 영등포구     5998
# 용산구      2685
# 은평구      5724
# 종로구      1419
# 중구       1835
# 중랑구      5089
# Name: 구, dtype: int64

# %%
price['구'].value_counts(normalize = True) * 100
# Out:
# 노원구     9.941
# 강서구     6.663
# 구로구     6.069
# 송파구     5.312
# 성북구     5.279
# 도봉구     4.914
# 강동구     4.861
# 강남구     4.805
# 서초구     4.427
# 영등포구    4.287
# 양천구     4.140
# 은평구     4.091
# 동대문구    3.928
# 중랑구     3.637
# 동작구     3.596
# 성동구     3.516
# 마포구     3.466
# 관악구     3.291
# 서대문구    3.258
# 강북구     2.415
# 금천구     2.211
# 용산구     1.919
# 광진구     1.651
# 중구      1.311
# 종로구     1.014
# Name: 구, dtype: float64

# %%
pd.crosstab(
    index = price['구'], 
    columns = price['거래년도'], 
    margins = True, 
    margins_name = '합계', 
    normalize = 'index'
)
# Out:
# 거래년도   2020   2021   2022
# 구
# 강남구   0.553  0.335  0.112
# 강동구   0.623  0.301  0.076
# 강북구   0.644  0.276  0.080
# 강서구   0.624  0.307  0.069
# 관악구   0.587  0.324  0.088
# 광진구   0.558  0.323  0.119
# 구로구   0.598  0.312  0.090
# 금천구   0.549  0.320  0.131
# 노원구   0.652  0.286  0.062
# 도봉구   0.666  0.276  0.059
# 동대문구  0.591  0.313  0.096
# 동작구   0.588  0.307  0.105
# 마포구   0.583  0.322  0.095
# 서대문구  0.602  0.317  0.081
# 서초구   0.537  0.354  0.109
# 성동구   0.618  0.309  0.073
# 성북구   0.612  0.320  0.068
# 송파구   0.623  0.287  0.090
# 양천구   0.602  0.326  0.072
# 영등포구  0.573  0.318  0.110
# 용산구   0.569  0.338  0.093
# 은평구   0.603  0.296  0.100
# 종로구   0.562  0.320  0.118
# 중구    0.560  0.334  0.106
# 중랑구   0.570  0.324  0.106
# 합계    0.602  0.310  0.087

# %%
# %whos
# Out:
# Variable   Type              Data/Info
# --------------------------------------
# chardet    module            <module 'chardet' from 'C<...>s\\chardet\\__init__.py'>
# cols       list              n=4
# file       BufferedReader    <_io.BufferedReader name='APT_Prep.csv'>
# fileName   str               APT_Prep.csv
# imsi       DataFrame                            아파트   <...>139917 rows x 15 columns]
# joblib     module            <module 'joblib' from 'C:<...>es\\joblib\\__init__.py'>
# locs       Series            0         False\n1       <...>ngth: 139917, dtype: bool
# np         module            <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os         module            <module 'os' (frozen)>
# pd         module            <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# price      DataFrame                            아파트   <...>139917 rows x 16 columns]
# pvt        DataFrame                size         sum  <...>495  0.67  145.0  12,203원
# ...

# %%
# %whos -v DataFrame
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# imsi       DataFrame                       아파트   <...>139917 rows x 15 columns]
# price      DataFrame                       아파트   <...>139917 rows x 16 columns]
# pvt        DataFrame           size         sum  <...>495  0.67  145.0  12,203원

# %%
df1 = price[price['거래금액'].ge(120)]
df2 = price[price['거래금액'].lt(120) & price['층'].ge(65)]

# %%
elong = price[['구', '금액구간']].value_counts()
elong
# Out:
# 구     금액구간
# 노원구   5천 미만    13538
# 강서구   5천 미만     8486
# 구로구   5천 미만     8272
# 성북구   5천 미만     6993
# 도봉구   5천 미만     6840
# 은평구   5천 미만     5526
# 강남구   5천 이상     5202
# 중랑구   5천 미만     5032
# 동대문구  5천 미만     4897
# 강동구   5천 미만     4769
# 영등포구  5천 미만     4674
# 관악구   5천 미만     4483
# 송파구   5천 이상     4377
# 양천구   5천 미만     4095
# 서초구   5천 이상     4017
# 서대문구  5천 미만     3809
# 동작구   5천 미만     3487
# 강북구   5천 미만     3368
# 송파구   5천 미만     3055
# 금천구   5천 미만     2987
# 마포구   5천 미만     2932
# 성동구   5천 이상     2588
#       5천 미만     2332
# 서초구   5천 미만     2177
# 강동구   5천 이상     2032
# 마포구   5천 이상     1917
# 양천구   5천 이상     1698
# 용산구   5천 이상     1619
# 동작구   5천 이상     1544
# 강남구   5천 미만     1521
# 중구    5천 미만     1468
# 광진구   5천 미만     1399
# 영등포구  5천 이상     1324
# 종로구   5천 미만     1196
# 용산구   5천 미만     1066
# 광진구   5천 이상      911
# 강서구   5천 이상      836
# 서대문구  5천 이상      749
# 동대문구  5천 이상      599
# 성북구   5천 이상      393
# 노원구   5천 이상      371
# 중구    5천 이상      367
# ...

# %%
elong = elong.reset_index()
elong
# Out:
#        구   금액구간      0
# 0    노원구  5천 미만  13538
# 1    강서구  5천 미만   8486
# 2    구로구  5천 미만   8272
# 3    성북구  5천 미만   6993
# 4    도봉구  5천 미만   6840
# 5    은평구  5천 미만   5526
# 6    강남구  5천 이상   5202
# 7    중랑구  5천 미만   5032
# 8   동대문구  5천 미만   4897
# 9    강동구  5천 미만   4769
# 10  영등포구  5천 미만   4674
# 11   관악구  5천 미만   4483
# 12   송파구  5천 이상   4377
# 13   양천구  5천 미만   4095
# 14   서초구  5천 이상   4017
# 15  서대문구  5천 미만   3809
# 16   동작구  5천 미만   3487
# 17   강북구  5천 미만   3368
# 18   송파구  5천 미만   3055
# 19   금천구  5천 미만   2987
# 20   마포구  5천 미만   2932
# 21   성동구  5천 이상   2588
# 22   성동구  5천 미만   2332
# 23   서초구  5천 미만   2177
# 24   강동구  5천 이상   2032
# 25   마포구  5천 이상   1917
# 26   양천구  5천 이상   1698
# 27   용산구  5천 이상   1619
# 28   동작구  5천 이상   1544
# 29   강남구  5천 미만   1521
# 30    중구  5천 미만   1468
# 31   광진구  5천 미만   1399
# 32  영등포구  5천 이상   1324
# 33   종로구  5천 미만   1196
# 34   용산구  5천 미만   1066
# 35   광진구  5천 이상    911
# 36   강서구  5천 이상    836
# 37  서대문구  5천 이상    749
# 38  동대문구  5천 이상    599
# ...

# %%
elong = elong.rename(columns = {0: '매매건수'})
elong
# Out:
#        구   금액구간   매매건수
# 0    노원구  5천 미만  13538
# 1    강서구  5천 미만   8486
# 2    구로구  5천 미만   8272
# 3    성북구  5천 미만   6993
# 4    도봉구  5천 미만   6840
# 5    은평구  5천 미만   5526
# 6    강남구  5천 이상   5202
# 7    중랑구  5천 미만   5032
# 8   동대문구  5천 미만   4897
# 9    강동구  5천 미만   4769
# 10  영등포구  5천 미만   4674
# 11   관악구  5천 미만   4483
# 12   송파구  5천 이상   4377
# 13   양천구  5천 미만   4095
# 14   서초구  5천 이상   4017
# 15  서대문구  5천 미만   3809
# 16   동작구  5천 미만   3487
# 17   강북구  5천 미만   3368
# 18   송파구  5천 미만   3055
# 19   금천구  5천 미만   2987
# 20   마포구  5천 미만   2932
# 21   성동구  5천 이상   2588
# 22   성동구  5천 미만   2332
# 23   서초구  5천 미만   2177
# 24   강동구  5천 이상   2032
# 25   마포구  5천 이상   1917
# 26   양천구  5천 이상   1698
# 27   용산구  5천 이상   1619
# 28   동작구  5천 이상   1544
# 29   강남구  5천 미만   1521
# 30    중구  5천 미만   1468
# 31   광진구  5천 미만   1399
# 32  영등포구  5천 이상   1324
# 33   종로구  5천 미만   1196
# 34   용산구  5천 미만   1066
# 35   광진구  5천 이상    911
# 36   강서구  5천 이상    836
# 37  서대문구  5천 이상    749
# 38  동대문구  5천 이상    599
# ...

# %%
elong = elong.sort_values(by = ['구', '금액구간'])
elong
# Out:
#        구   금액구간   매매건수
# 29   강남구  5천 미만   1521
# 6    강남구  5천 이상   5202
# 9    강동구  5천 미만   4769
# 24   강동구  5천 이상   2032
# 17   강북구  5천 미만   3368
# 49   강북구  5천 이상     11
# 1    강서구  5천 미만   8486
# 36   강서구  5천 이상    836
# 11   관악구  5천 미만   4483
# 45   관악구  5천 이상    121
# 31   광진구  5천 미만   1399
# 35   광진구  5천 이상    911
# 2    구로구  5천 미만   8272
# 43   구로구  5천 이상    219
# 19   금천구  5천 미만   2987
# 46   금천구  5천 이상    106
# 0    노원구  5천 미만  13538
# 40   노원구  5천 이상    371
# 4    도봉구  5천 미만   6840
# 48   도봉구  5천 이상     36
# 8   동대문구  5천 미만   4897
# 38  동대문구  5천 이상    599
# 16   동작구  5천 미만   3487
# 28   동작구  5천 이상   1544
# 20   마포구  5천 미만   2932
# 25   마포구  5천 이상   1917
# 15  서대문구  5천 미만   3809
# 37  서대문구  5천 이상    749
# 23   서초구  5천 미만   2177
# 14   서초구  5천 이상   4017
# 22   성동구  5천 미만   2332
# 21   성동구  5천 이상   2588
# 3    성북구  5천 미만   6993
# 39   성북구  5천 이상    393
# 18   송파구  5천 미만   3055
# 12   송파구  5천 이상   4377
# 13   양천구  5천 미만   4095
# 26   양천구  5천 이상   1698
# 10  영등포구  5천 미만   4674
# ...

# %%
elong.head()
# Out:
#       구   금액구간  매매건수
# 29  강남구  5천 미만  1521
# 6   강남구  5천 이상  5202
# 9   강동구  5천 미만  4769
# 24  강동구  5천 이상  2032
# 17  강북구  5천 미만  3368

# %%
widen = elong.pivot(index = '구', columns = '금액구간', values = '매매건수')
widen
# Out:
# 금액구간  5천 미만  5천 이상
# 구
# 강남구    1521   5202
# 강동구    4769   2032
# 강북구    3368     11
# 강서구    8486    836
# 관악구    4483    121
# 광진구    1399    911
# 구로구    8272    219
# 금천구    2987    106
# 노원구   13538    371
# 도봉구    6840     36
# 동대문구   4897    599
# 동작구    3487   1544
# 마포구    2932   1917
# 서대문구   3809    749
# 서초구    2177   4017
# 성동구    2332   2588
# 성북구    6993    393
# 송파구    3055   4377
# 양천구    4095   1698
# 영등포구   4674   1324
# 용산구    1066   1619
# 은평구    5526    198
# 종로구    1196    223
# 중구     1468    367
# 중랑구    5032     57

# %%
widen.head()
# Out:
#      구  5천 미만  5천 이상
# 0  강남구   1521   5202
# 1  강동구   4769   2032
# 2  강북구   3368     11
# 3  강서구   8486    836
# 4  관악구   4483    121

# %%
widen.index
# Out:
# Index(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구',
#        '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구',
#        '용산구', '은평구', '종로구', '중구', '중랑구'],
#       dtype='object', name='구')

# %%
widen.index.name
# Out:
# '구'

# %%
widen = widen.reset_index()
widen.head()
# Out:
# 금액구간    구  5천 미만  5천 이상
# 0     강남구   1521   5202
# 1     강동구   4769   2032
# 2     강북구   3368     11
# 3     강서구   8486    836
# 4     관악구   4483    121

# %%
widen.columns
# Out:
# Index(['구', '5천 미만', '5천 이상'], dtype='object', name='금액구간')

# %%
widen.columns.name
# Out:
# '금액구간'

# %%
widen.columns.name = ''

# %%
widen.columns
# Out:
# Index(['구', '5천 미만', '5천 이상'], dtype='object', name='')

# %%
widen.columns.name = None

# %%
widen.columns
# Out:
# Index(['구', '5천 미만', '5천 이상'], dtype='object')

# %%
widen.head()
# Out:
#      구  5천 미만  5천 이상
# 0  강남구   1521   5202
# 1  강동구   4769   2032
# 2  강북구   3368     11
# 3  강서구   8486    836
# 4  관악구   4483    121

# %%
elong = widen.melt(
    id_vars = '구', 
    value_vars = ['5천 미만', '5천 이상'], 
    var_name = '금액구분', 
    value_name = '거래건수'
)

# %%
elong.sort_values(by = ['구', '금액구분']).reset_index(drop = True)
# Out:
#        구   금액구분   거래건수
# 0    강남구  5천 미만   1521
# 1    강남구  5천 이상   5202
# 2    강동구  5천 미만   4769
# 3    강동구  5천 이상   2032
# 4    강북구  5천 미만   3368
# 5    강북구  5천 이상     11
# 6    강서구  5천 미만   8486
# 7    강서구  5천 이상    836
# 8    관악구  5천 미만   4483
# 9    관악구  5천 이상    121
# 10   광진구  5천 미만   1399
# 11   광진구  5천 이상    911
# 12   구로구  5천 미만   8272
# 13   구로구  5천 이상    219
# 14   금천구  5천 미만   2987
# 15   금천구  5천 이상    106
# 16   노원구  5천 미만  13538
# 17   노원구  5천 이상    371
# 18   도봉구  5천 미만   6840
# 19   도봉구  5천 이상     36
# 20  동대문구  5천 미만   4897
# 21  동대문구  5천 이상    599
# 22   동작구  5천 미만   3487
# 23   동작구  5천 이상   1544
# 24   마포구  5천 미만   2932
# 25   마포구  5천 이상   1917
# 26  서대문구  5천 미만   3809
# 27  서대문구  5천 이상    749
# 28   서초구  5천 미만   2177
# 29   서초구  5천 이상   4017
# 30   성동구  5천 미만   2332
# 31   성동구  5천 이상   2588
# 32   성북구  5천 미만   6993
# 33   성북구  5천 이상    393
# 34   송파구  5천 미만   3055
# 35   송파구  5천 이상   4377
# 36   양천구  5천 미만   4095
# 37   양천구  5천 이상   1698
# 38  영등포구  5천 미만   4674
# ...

# %%
df1.columns.equals(df2.columns)
# Out:
# True

# %%
pd.concat(objs = [df1, df2], ignore_index = True)
# Out:
#          아파트      시    구      동       지번  건축년도        거래일     전용면적   층  \
# 0      파르크한남  서울특별시  용산구    한남동      410  2020 2021-12-13  268.950   2
# 1      파르크한남  서울특별시  용산구    한남동      410  2020 2022-04-30  268.670   5
# 2      PH129  서울특별시  강남구    청담동      129  2020 2022-04-28  273.960  16
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020 2022-09-30  264.546  47
# 4    현대하이페리온  서울특별시  양천구     목동      916  2003 2020-07-03  154.050  66
# 5     타워팰리스3  서울특별시  강남구    도곡동   467-29  2004 2020-07-25  235.740  67
# 6     타워팰리스3  서울특별시  강남구    도곡동   467-29  2004 2020-10-27  185.622  66
# 7     타워팰리스3  서울특별시  강남구    도곡동   467-29  2004 2021-06-24  214.967  66
#
#      거래금액       평당금액  거래년도  경과년수  거래월   금액구간                       주소
# 0  120.00  14723.926  2021     1  12월  5천 이상        서울특별시 용산구 한남동 410
# 1  135.00  16581.680  2022     2  04월  5천 이상        서울특별시 용산구 한남동 410
# 2  145.00  17466.053  2022     2  04월  5천 이상        서울특별시 강남구 청담동 129
# ...

# %%
df2 = df2.rename(columns = {'아파트': '아파트명'})

# %%
df1.columns.equals(df2.columns)
# Out:
# False

# %%
pd.concat(objs = [df1, df2], ignore_index = True)
# Out:
#          아파트      시    구      동       지번  건축년도        거래일     전용면적   층  \
# 0      파르크한남  서울특별시  용산구    한남동      410  2020 2021-12-13  268.950   2
# 1      파르크한남  서울특별시  용산구    한남동      410  2020 2022-04-30  268.670   5
# 2      PH129  서울특별시  강남구    청담동      129  2020 2022-04-28  273.960  16
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020 2022-09-30  264.546  47
# 4        NaN  서울특별시  양천구     목동      916  2003 2020-07-03  154.050  66
# 5        NaN  서울특별시  강남구    도곡동   467-29  2004 2020-07-25  235.740  67
# 6        NaN  서울특별시  강남구    도곡동   467-29  2004 2020-10-27  185.622  66
# 7        NaN  서울특별시  강남구    도곡동   467-29  2004 2021-06-24  214.967  66
#
#      거래금액       평당금액  거래년도  경과년수  거래월   금액구간                       주소     아파트명
# 0  120.00  14723.926  2021     1  12월  5천 이상        서울특별시 용산구 한남동 410      NaN
# 1  135.00  16581.680  2022     2  04월  5천 이상        서울특별시 용산구 한남동 410      NaN
# 2  145.00  17466.053  2022     2  04월  5천 이상        서울특별시 강남구 청담동 129      NaN
# ...

# %%
pd.concat(objs = [df1, df2], axis = 1)
# Out:
#               아파트      시    구      동       지번    건축년도        거래일     전용면적  \
# 126596      파르크한남  서울특별시  용산구    한남동      410  2020.0 2021-12-13  268.950
# 131283      파르크한남  서울특별시  용산구    한남동      410  2020.0 2022-04-30  268.670
# 132779      PH129  서울특별시  강남구    청담동      129  2020.0 2022-04-28  273.960
# 137418  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020.0 2022-09-30  264.546
# 50867         NaN    NaN  NaN    NaN      NaN     NaN        NaT      NaN
# 55000         NaN    NaN  NaN    NaN      NaN     NaN        NaT      NaN
# 69573         NaN    NaN  NaN    NaN      NaN     NaN        NaT      NaN
# 110650        NaN    NaN  NaN    NaN      NaN     NaN        NaT      NaN
#
#            층   거래금액  ...        거래일     전용면적     층   거래금액      평당금액    거래년도  \
# 126596   2.0  120.0  ...        NaT      NaN   NaN    NaN       NaN     NaN
# 131283   5.0  135.0  ...        NaT      NaN   NaN    NaN       NaN     NaN
# ...

# %%
df1 = df1.reset_index(drop = True)
df2 = df2.reset_index(drop = True)

# %%
pd.concat(objs = [df1, df2], axis = 1)
# Out:
#          아파트      시    구      동       지번  건축년도        거래일     전용면적   층   거래금액  \
# 0      파르크한남  서울특별시  용산구    한남동      410  2020 2021-12-13  268.950   2  120.0
# 1      파르크한남  서울특별시  용산구    한남동      410  2020 2022-04-30  268.670   5  135.0
# 2      PH129  서울특별시  강남구    청담동      129  2020 2022-04-28  273.960  16  145.0
# 3  아크로서울포레스트  서울특별시  성동구  성수동1가  685-700  2020 2022-09-30  264.546  47  130.0
#
#    ...        거래일     전용면적   층   거래금액      평당금액  거래년도 경과년수  거래월   금액구간  \
# 0  ... 2020-07-03  154.050  66  24.00  5141.188  2020   17  07월  5천 이상
# 1  ... 2020-07-25  235.740  67  54.25  7594.172  2020   16  07월  5천 이상
# 2  ... 2020-10-27  185.622  66  38.00  6755.665  2020   16  10월  5천 이상
# 3  ... 2021-06-24  214.967  66  45.80  7030.847  2021   17  06월  5천 이상
#
#                      주소
# 0      서울특별시 양천구 목동 916
# 1  서울특별시 강남구 도곡동 467-29
# 2  서울특별시 강남구 도곡동 467-29
# 3  서울특별시 강남구 도곡동 467-29
#
# [4 rows x 32 columns]

# %%
cols1 = ['시', '구', '동', '지번']
cols2 = ['지번', '시', '구', '동']

# %%
df11 = df1[cols1]
df21 = df2[cols2]

# %%
df11
# Out:
#        시    구      동       지번
# 0  서울특별시  용산구    한남동      410
# 1  서울특별시  용산구    한남동      410
# 2  서울특별시  강남구    청담동      129
# 3  서울특별시  성동구  성수동1가  685-700

# %%
df21
# Out:
#        지번      시    구    동
# 0     916  서울특별시  양천구   목동
# 1  467-29  서울특별시  강남구  도곡동
# 2  467-29  서울특별시  강남구  도곡동
# 3  467-29  서울특별시  강남구  도곡동

# %%
df11.columns.equals(df21.columns)
# Out:
# False

# %%
pd.concat(objs = [df11, df21], ignore_index = True)
# Out:
#        시    구      동       지번
# 0  서울특별시  용산구    한남동      410
# 1  서울특별시  용산구    한남동      410
# 2  서울특별시  강남구    청담동      129
# 3  서울특별시  성동구  성수동1가  685-700
# 4  서울특별시  양천구     목동      916
# 5  서울특별시  강남구    도곡동   467-29
# 6  서울특별시  강남구    도곡동   467-29
# 7  서울특별시  강남구    도곡동   467-29

# %%
df21 = df21[df11.columns]

# %%
os.listdir()
# Out:
# ['App_Usage.csv',
#  'APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged.csv',
#  'APT_Merged.xlsx',
#  'APT_Prep.csv',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'APT_Price_Seoul_Copy.xlsx',
#  'NA_Sample.xlsx',
#  'Online_Mall.csv',
#  'pivot_table.xlsx',
#  'test.xlsx']

# %%
detail = pd.read_excel('APT_Detail_Seoul_2022.xlsx')

# %%
detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10290 entries, 0 to 10289
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   아파트ID   10290 non-null  int64
#  1   아파트명    10290 non-null  object
#  2   지번주소    10290 non-null  object
#  3   위도      10290 non-null  float64
#  4   경도      10290 non-null  float64
#  5   동수      10290 non-null  int64
#  6   세대수     10290 non-null  int64
#  7   임대수     10290 non-null  int64
#  8   용적률     10290 non-null  int64
#  9   건폐율     10290 non-null  int64
#  10  주차대수    10290 non-null  int64
#  11  건설사     9746 non-null   object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 964.8+ KB

# %%
detail.head()
# Out:
#     아파트ID          아파트명                지번주소      위도       경도  동수   세대수  임대수  \
# 0  146479         YH빌리지  서울시 강남구 개포동 1237-8  37.478  127.047   1    16    0
# 1  119219     개포래미안포레스트    서울시 강남구 개포동 1282  37.478  127.054  31  2296  120
# 2  140057  개포비버리하임(도시형)  서울시 강남구 개포동 1193-5  37.475  127.049   2    29    0
# 3  107513       개포상지리츠빌   서울시 강남구 개포동 176-1  37.487  127.060   1    18    0
# 4    8928          개포자이    서울시 강남구 개포동 12-2  37.496  127.077   4   212    0
#
#    용적률  건폐율  주차대수        건설사
# 0  297   59     9  (주)세담종합건설
# 1  249   21  3961    삼성물산(주)
# 2  199   57    30   (주)덕인컨스텍
# 3  202   31    41    상지건영(주)
# 4  250   18   502    LG건설(주)

# %%
len(set(price['아파트']) & set(detail['아파트명']))
# Out:
# 2556

# %%
len(set(price['주소']) & set(detail['지번주소']))
# Out:
# 0

# %%
price['주소']
# Out:
# 0            서울특별시 종로구 필운동 254
# 1            서울특별시 종로구 사직동 9-1
# 2            서울특별시 종로구 내수동 167
# 3         서울특별시 종로구 내수동 110-15
# 4             서울특별시 종로구 내수동 95
#                   ...
# 139912    서울특별시 강동구 암사동 493-14
# 139913     서울특별시 강동구 암사동 414-2
# 139914       서울특별시 강동구 암사동 509
# 139915     서울특별시 강동구 성내동 452-2
# 139916       서울특별시 강동구 강일동 114
# Name: 주소, Length: 139917, dtype: object

# %%
detail['지번주소']
# Out:
# 0        서울시 강남구 개포동 1237-8
# 1          서울시 강남구 개포동 1282
# 2        서울시 강남구 개포동 1193-5
# 3         서울시 강남구 개포동 176-1
# 4          서울시 강남구 개포동 12-2
#                 ...
# 10285    서울시 중랑구 중화동 318-81
# 10286     서울시 중랑구 중화동 19-16
# 10287       서울시 중랑구 중화동 450
# 10288    서울시 중랑구 중화동 274-51
# 10289        서울시 중랑구 중화동 11
# Name: 지번주소, Length: 10290, dtype: object

# %%
price['주소'] = price['주소'].str.replace('특별', '')

# %%
len(set(price['주소']) & set(detail['지번주소']))
# Out:
# 6773

# %%
for i in range(5):
    np.random.seed(seed = 1234)
    lotto = np.random.choice(a = range(1, 46), size = 6, replace = False)
    lotto.sort()
    print(lotto)
# Out:
# [ 9 15 26 35 40 45]
# [ 9 15 26 35 40 45]
# [ 9 15 26 35 40 45]
# [ 9 15 26 35 40 45]
# [ 9 15 26 35 40 45]

# %%
np.random.seed(1)

# %%
nums = np.random.choice(range(1, 5), 5)
nums
# Out:
# array([2, 4, 1, 1, 4])

# %%
nums = pd.Series(nums)
nums
# Out:
# 0    2
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
nums.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
nums[nums.duplicated()]
# Out:
# 3    1
# 4    4
# dtype: int32

# %%
nums.duplicated(keep = 'last')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
nums[nums.duplicated(keep = 'last')]
# Out:
# 1    4
# 2    1
# dtype: int32

# %%
nums.duplicated(keep = False)
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
nums[nums.duplicated(keep = False)]
# Out:
# 1    4
# 2    1
# 3    1
# 4    4
# dtype: int32

# %%
dup = detail['지번주소'].duplicated(keep = False)

# %%
detail[dup].sort_values(by = ['지번주소'])
# Out:
#        아파트ID                  아파트명                     지번주소      위도       경도  \
# 18       419                    대청           서울시 강남구 개포동 12  37.495  127.077
# 19       483                 대치2단지           서울시 강남구 개포동 12  37.495  127.075
# 8       1303               개포주공6단지          서울시 강남구 개포동 185  37.489  127.070
# 9       1307               개포주공7단지          서울시 강남구 개포동 185  37.490  127.072
# 474      724                현대6,7차         서울시 강남구 압구정동 456  37.530  127.029
# 475    27498         현대65동(대림아크로빌)         서울시 강남구 압구정동 456  37.532  127.032
# 956      902               주공고층3단지        서울시 강동구 둔촌동 174-1  37.524  127.139
# 959      901               주공저층2단지        서울시 강동구 둔촌동 174-1  37.523  127.136
# 1325  133403            미사아름채(도시형)       서울시 강동구 천호동 452-15  37.538  127.128
# 1326  133402           미사아름채(주상복합)       서울시 강동구 천호동 452-15  37.538  127.128
# 1539  145243   에피소드수유838(민간임대,도시형)          서울시 강북구 수유동 740  37.637  127.023
# ...

# %%
detail = detail[~detail['지번주소'].duplicated()]

# %%
detail.shape[0]
# Out:
# 10261

# %%
pd.merge(
    left = price, 
    right = detail[['지번주소', 'A', 'B', 'C']], 
    how = 'inner', 
    left_on = '주소', 
    right_on = '지번주소'
)
# Out:
#                 아파트      시    구    동     지번  건축년도        거래일    전용면적   층  \
# 0       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2020-01-03  111.97   6
# 1       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2020-02-21  108.95   7
# 2       신동아블루아광화문의꿈  서울특별시  종로구  필운동    254  2007 2021-10-25  111.97   8
# 3             세종로대우  서울특별시  종로구  내수동    167  1994 2020-01-06  109.91  11
# 4             세종로대우  서울특별시  종로구  내수동    167  1994 2020-02-20   66.96  12
# ...             ...    ...  ...  ...    ...   ...        ...     ...  ..
# 132808        더메종건대  서울특별시  광진구  화양동   23-5  2022 2022-12-23   17.78  12
# 132809     삼영N-CITY  서울특별시  은평구  응암동  96-19  2015 2022-12-24   45.91   6
# 132810        길훈로즈빌  서울특별시  양천구  신정동   1297  2002 2022-12-16   84.95  14
# 132811        길훈로즈빌  서울특별시  양천구  신정동   1297  2002 2022-12-19   84.95  14
# 132812    강동리버스트4단지  서울특별시  강동구  강일동    114  2020 2022-12-29   59.99   7
#
#           거래금액  ...               지번주소      위도       경도  동수   세대수  임대수  용적률  \
# ...

# %%
pd.merge(
    left = price, 
    right = detail, 
    how = 'outer', 
    left_on = '주소', 
    right_on = '지번주소'
)
# Out:
#                    아파트      시    구    동   지번    건축년도        거래일    전용면적    층  \
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007.0 2020-01-03  111.97  6.0
# 1          신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007.0 2020-02-21  108.95  7.0
# 2          신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007.0 2021-10-25  111.97  8.0
# 3       광화문스페이스본(106동)  서울특별시  종로구  사직동  9-1  2008.0 2020-01-02  163.33  2.0
# 4       광화문스페이스본(106동)  서울특별시  종로구  사직동  9-1  2008.0 2020-06-22  150.40  7.0
# ...                ...    ...  ...  ...  ...     ...        ...     ...  ...
# 143400             NaN    NaN  NaN  NaN  NaN     NaN        NaT     NaN  NaN
# 143401             NaN    NaN  NaN  NaN  NaN     NaN        NaT     NaN  NaN
# 143402             NaN    NaN  NaN  NaN  NaN     NaN        NaT     NaN  NaN
# 143403             NaN    NaN  NaN  NaN  NaN     NaN        NaT     NaN  NaN
# 143404             NaN    NaN  NaN  NaN  NaN     NaN        NaT     NaN  NaN
#
# ...

# %%
pd.merge(
    left = price, 
    right = detail, 
    how = 'left', 
    left_on = '주소', 
    right_on = '지번주소'
)
# Out:
#                    아파트      시    구    동      지번  건축년도        거래일    전용면적   층  \
# 0          신동아블루아광화문의꿈  서울특별시  종로구  필운동     254  2007 2020-01-03  111.97   6
# 1       광화문스페이스본(106동)  서울특별시  종로구  사직동     9-1  2008 2020-01-02  163.33   2
# 2                세종로대우  서울특별시  종로구  내수동     167  1994 2020-01-06  109.91  11
# 3                 킹스매너  서울특별시  종로구  내수동  110-15  2004 2020-01-09  194.43   4
# 4             경희궁파크팰리스  서울특별시  종로구  내수동      95  2003 2020-01-20  148.09   8
# ...                ...    ...  ...  ...     ...   ...        ...     ...  ..
# 139912           중앙하이츠  서울특별시  강동구  암사동  493-14  1998 2022-12-03   59.52   8
# 139913         롯데캐슬퍼스트  서울특별시  강동구  암사동   414-2  2008 2022-12-06  111.22  10
# 139914         선사현대아파트  서울특별시  강동구  암사동     509  2000 2022-12-10   59.64  17
# 139915         파크뷰진도맨션  서울특별시  강동구  성내동   452-2  1996 2022-12-06  208.92  18
# 139916       강동리버스트4단지  서울특별시  강동구  강일동     114  2020 2022-12-29   59.99   7
#
# ...

# %%
price.columns
# Out:
# Index(['아파트', '시', '구', '동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액', '평당금액',
#        '거래년도', '경과년수', '거래월', '금액구간', '주소'],
#       dtype='object')

# %%
detail.columns
# Out:
# Index(['아파트ID', '아파트명', '지번주소', '위도', '경도', '동수', '세대수', '임대수', '용적률', '건폐율',
#        '주차대수', '건설사'],
#       dtype='object')

# %%
cols1 = ['아파트', '건축년도', '거래일', '전용면적', '층', '거래금액', '주소']
cols2 = ['지번주소', '세대수', '임대수', '용적률', '건폐율', '주차대수', '건설사']

# %%
pd.merge(
    left = price[cols1], 
    right = detail[cols2], 
    how = 'inner', 
    left_on = '주소', 
    right_on = '지번주소'
)
# Out:
#                 아파트  건축년도        거래일    전용면적   층    거래금액                 주소  \
# 0       신동아블루아광화문의꿈  2007 2020-01-03  111.97   6  10.000    서울시 종로구 필운동 254
# 1       신동아블루아광화문의꿈  2007 2020-02-21  108.95   7   9.600    서울시 종로구 필운동 254
# 2       신동아블루아광화문의꿈  2007 2021-10-25  111.97   8  14.000    서울시 종로구 필운동 254
# 3             세종로대우  1994 2020-01-06  109.91  11   8.800    서울시 종로구 내수동 167
# 4             세종로대우  1994 2020-02-20   66.96  12   6.150    서울시 종로구 내수동 167
# ...             ...   ...        ...     ...  ..     ...                ...
# 132808        더메종건대  2022 2022-12-23   17.78  12   2.585   서울시 광진구 화양동 23-5
# 132809     삼영N-CITY  2015 2022-12-24   45.91   6   3.170  서울시 은평구 응암동 96-19
# 132810        길훈로즈빌  2002 2022-12-16   84.95  14  11.600   서울시 양천구 신정동 1297
# 132811        길훈로즈빌  2002 2022-12-19   84.95  14  11.600   서울시 양천구 신정동 1297
# 132812    강동리버스트4단지  2020 2022-12-29   59.99   7   5.500    서울시 강동구 강일동 114
#
# ...

# %%
detail = detail.rename(columns = {'지번주소': '주소'})

# %%
set(price.columns) & set(detail.columns)
# Out:
# {'주소'}

# %%
pd.merge(
    left = price, 
    right = detail, 
    how = 'inner', 
    on = '주소'
).shape[0]
# Out:
# 132813

# %%
df3 = price[['아파트', '주소', '거래금액']]
df4 = detail[['아파트명', '주소', '세대수']]

# %%
set(df3.columns) & set(df4.columns)
# Out:
# {'주소'}

# %%
pd.merge(left = df3, right = df4, how = 'inner', on = '주소')
# Out:
#                 아파트                 주소    거래금액               아파트명   세대수
# 0       신동아블루아광화문의꿈    서울시 종로구 필운동 254  10.000  신동아블루아광화문의꿈(주상복합)    28
# 1       신동아블루아광화문의꿈    서울시 종로구 필운동 254   9.600  신동아블루아광화문의꿈(주상복합)    28
# 2       신동아블루아광화문의꿈    서울시 종로구 필운동 254  14.000  신동아블루아광화문의꿈(주상복합)    28
# 3             세종로대우    서울시 종로구 내수동 167   8.800        세종로대우(주상복합)    60
# 4             세종로대우    서울시 종로구 내수동 167   6.150        세종로대우(주상복합)    60
# ...             ...                ...     ...                ...   ...
# 132808        더메종건대   서울시 광진구 화양동 23-5   2.585           더메종(도시형)    99
# 132809     삼영N-CITY  서울시 은평구 응암동 96-19   3.170     삼영N-CITY(주상복합)    18
# 132810        길훈로즈빌   서울시 양천구 신정동 1297  11.600              길훈로즈빌    49
# 132811        길훈로즈빌   서울시 양천구 신정동 1297  11.600              길훈로즈빌    49
# 132812    강동리버스트4단지    서울시 강동구 강일동 114   5.500          강동리버스트4단지  1239
#
# [132813 rows x 5 columns]

# %%
df4 = df4.rename(columns = {'아파트명': '아파트'})

# %%
set(df3.columns) & set(df4.columns)
# Out:
# {'아파트', '주소'}

# %%
pd.merge(left = df3, right = df4, how = 'inner', on = '주소')
# Out:
#               아파트_x                 주소    거래금액              아파트_y   세대수
# 0       신동아블루아광화문의꿈    서울시 종로구 필운동 254  10.000  신동아블루아광화문의꿈(주상복합)    28
# 1       신동아블루아광화문의꿈    서울시 종로구 필운동 254   9.600  신동아블루아광화문의꿈(주상복합)    28
# 2       신동아블루아광화문의꿈    서울시 종로구 필운동 254  14.000  신동아블루아광화문의꿈(주상복합)    28
# 3             세종로대우    서울시 종로구 내수동 167   8.800        세종로대우(주상복합)    60
# 4             세종로대우    서울시 종로구 내수동 167   6.150        세종로대우(주상복합)    60
# ...             ...                ...     ...                ...   ...
# 132808        더메종건대   서울시 광진구 화양동 23-5   2.585           더메종(도시형)    99
# 132809     삼영N-CITY  서울시 은평구 응암동 96-19   3.170     삼영N-CITY(주상복합)    18
# 132810        길훈로즈빌   서울시 양천구 신정동 1297  11.600              길훈로즈빌    49
# 132811        길훈로즈빌   서울시 양천구 신정동 1297  11.600              길훈로즈빌    49
# 132812    강동리버스트4단지    서울시 강동구 강일동 114   5.500          강동리버스트4단지  1239
#
# [132813 rows x 5 columns]

# %%
pd.merge(left = df3, right = df4, how = 'inner')
# Out:
#              아파트                  주소  거래금액   세대수
# 0           킹스매너  서울시 종로구 내수동 110-15  13.0    18
# 1           킹스매너  서울시 종로구 내수동 110-15  14.7    18
# 2           킹스매너  서울시 종로구 내수동 110-15  14.2    18
# 3           킹스매너  서울시 종로구 내수동 110-15   8.9    18
# 4           킹스매너  서울시 종로구 내수동 110-15  15.8    18
# ...          ...                 ...   ...   ...
# 53710      홍익봄마을  서울시 송파구 송파동 173-12   9.0    43
# 53711      흥화빌라트  서울시 광진구 광장동 188-27  15.5    19
# 53712      길훈로즈빌    서울시 양천구 신정동 1297  11.6    49
# 53713      길훈로즈빌    서울시 양천구 신정동 1297  11.6    49
# 53714  강동리버스트4단지     서울시 강동구 강일동 114   5.5  1239
#
# [53715 rows x 4 columns]

# %%
apt = pd.merge(left = price, right = detail, how = 'inner', on = '주소')

# %%
apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132813 entries, 0 to 132812
# Data columns (total 27 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     132813 non-null  object
#  1   시       132813 non-null  object
#  2   구       132813 non-null  object
#  3   동       132813 non-null  object
#  4   지번      132813 non-null  object
#  5   건축년도    132813 non-null  int64
#  6   거래일     132813 non-null  datetime64[ns]
#  7   전용면적    132813 non-null  float64
#  8   층       132813 non-null  int64
#  9   거래금액    132813 non-null  float64
#  10  평당금액    132813 non-null  float64
#  11  거래년도    132813 non-null  int64
#  12  경과년수    132813 non-null  int64
#  13  거래월     132813 non-null  object
#  14  금액구간    132813 non-null  object
#  15  주소      132813 non-null  object
#  16  아파트ID   132813 non-null  int64
#  17  아파트명    132813 non-null  object
#  18  위도      132813 non-null  float64
#  19  경도      132813 non-null  float64
# ...

# %%
apt.columns
# Out:
# Index(['아파트', '시', '구', '동', '지번', '건축년도', '거래일', '전용면적', '층', '거래금액', '평당금액',
#        '거래년도', '경과년수', '거래월', '금액구간', '주소', '아파트ID', '아파트명', '위도', '경도', '동수',
#        '세대수', '임대수', '용적률', '건폐율', '주차대수', '건설사'],
#       dtype='object')

# %%
apt = apt.drop(columns = ['주소', '아파트ID', '아파트명'])

# %%
# %time apt.to_excel('test.xlsx', index = False)
# Out:
# CPU times: total: 57.8 s
# Wall time: 1min 1s

# %%
# %time apt.to_csv('test.csv', index = False)
# Out:
# CPU times: total: 1.48 s
# Wall time: 1.76 s

# %%
# %time joblib.dump(value = apt, filename = 'test.z')
# Out:
# CPU times: total: 359 ms
# Wall time: 435 ms
# ['test.z']
