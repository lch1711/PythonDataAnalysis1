# %%
import os
import joblib
import numpy as np
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hdsce\\Documents\\PythonDataAnalysis1\\live'

# %%
os.chdir('../data')

# %%
os.listdir()
# Out:
# ['APT_Detail_Seoul_2022.csv',
#  'APT_Detail_Seoul_2022.xlsx',
#  'APT_Merged_Seoul_2022.txt',
#  'APT_Merged_Seoul_2022.xlsx',
#  'APT_Merged_Seoul_2022.z',
#  'APT_Price_Seoul_2020_2022.csv',
#  'APT_Price_Seoul_2020_2022.xlsx',
#  'APT_Price_Seoul_2020_2022.z',
#  'NA_Sample.xlsx',
#  'online_mall.csv']

# %%
[file for file in os.listdir() if 'Merged' in file]
# Out:
# ['APT_Merged_Seoul_2022.txt',
#  'APT_Merged_Seoul_2022.xlsx',
#  'APT_Merged_Seoul_2022.z']

# %%
apt = joblib.load(filename = 'APT_Merged_Seoul_2022.z')

# %%
apt = pd.read_csv('APT_Merged_Seoul_2022.txt')

# %%
apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132813 entries, 0 to 132812
# Data columns (total 24 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   아파트     132813 non-null  object
#  1   시       132813 non-null  object
#  2   구       132813 non-null  object
#  3   동       132813 non-null  object
#  4   지번      132813 non-null  object
#  5   건축년도    132813 non-null  int64
#  6   거래일     132813 non-null  object
#  7   전용면적    132813 non-null  float64
#  8   층       132813 non-null  int64
#  9   거래금액    132813 non-null  float64
#  10  평당금액    132813 non-null  float64
#  11  거래년도    132813 non-null  int64
#  12  경과년수    132813 non-null  int64
#  13  거래월     132813 non-null  object
#  14  금액구분    132813 non-null  object
#  15  위도      132813 non-null  float64
#  16  경도      132813 non-null  float64
#  17  동수      132813 non-null  int64
#  18  세대수     132813 non-null  int64
#  19  임대수     132813 non-null  int64
#  20  용적률     132813 non-null  int64
#  21  건폐율     132813 non-null  int64
#  22  주차대수    132813 non-null  int64
#  23  건설사     129990 non-null  object
# dtypes: float64(5), int64(10), object(9)
# memory usage: 24.3+ MB

# %%
apt['거래일'] = apt['거래일'].astype(np.datetime64)

# %%
apt.head()
# Out:
#            아파트      시    구    동   지번  건축년도        거래일    전용면적   층   거래금액  ...  \
# 0  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-01-03  111.97   6  10.00  ...
# 1  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-02-21  108.95   7   9.60  ...
# 2  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2021-10-25  111.97   8  14.00  ...
# 3        세종로대우  서울특별시  종로구  내수동  167  1994 2020-01-06  109.91  11   8.80  ...
# 4        세종로대우  서울특별시  종로구  내수동  167  1994 2020-02-20   66.96  12   6.15  ...
#
#     금액구분         위도          경도 동수 세대수  임대수  용적률  건폐율  주차대수         건설사
# 0  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 1  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 2  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 3  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
# 4  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
#
# [5 rows x 24 columns]

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
# import matplotlib.font_manager as fm

# %% [raw]
# sns.histplot(data = apt, x = '거래금액')
# plt.title(label = '아파트 거래금액 분포')
# plt.show()

# %% [raw]
# fontList = fm.findSystemFonts(fontext = 'ttf')

# %% [raw]
# len(fontList)

# %% [raw]
# fontPath = [font for font in fontList if 'Gowun' in font]

# %% [raw]
# for font in fontPath:
#     print(fm.FontProperties(fname = font).get_name())

# %% [raw]
# plt.rc(group = 'font', family = 'Gowun Dodum', size = 10)
# plt.rc(group = 'figure', figsize = (8, 8), dpi = 100)
# plt.rc(group = 'axes', unicode_minus = False)
# plt.rc(group = 'legend', frameon = True, fc = '1', ec = '0')

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\hdsce\\Documents\\PythonDataAnalysis1\\live',
#  'C:\\Users\\hdsce\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'C:\\Users\\hdsce\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'C:\\Users\\hdsce\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'C:\\Users\\hdsce\\AppData\\Local\\Programs\\Python\\Python310',
#  'C:\\Users\\hdsce\\ve310',
#  '',
#  'C:\\Users\\hdsce\\ve310\\lib\\site-packages',
#  'C:\\Users\\hdsce\\ve310\\lib\\site-packages\\win32',
#  'C:\\Users\\hdsce\\ve310\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\hdsce\\ve310\\lib\\site-packages\\Pythonwin']

# %%
from GraphicSetting import *

# %%
sns.histplot(data = apt, x = '거래금액')
plt.title(label = '아파트 거래금액 분포')
plt.show()

# %%
sns.histplot(data = apt, x = '거래금액')
plt.title(label = '아파트 거래금액 분포');

# %%
sns.histplot(data = apt, x = '거래금액', bins = 75, fc = '1', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', binwidth = 2, fc = '1', ec = '0');

# %%
apt['거래금액'].describe()
# Out:
# count    132813.000000
# mean          9.203529
# std           6.638999
# min           0.660000
# 25%           5.200000
# 50%           7.600000
# 75%          11.300000
# max         145.000000
# Name: 거래금액, dtype: float64

# %%
apt['거래금액'].describe()[['min', 'max']]
# Out:
# min      0.66
# max    145.00
# Name: 거래금액, dtype: float64

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 150), binwidth = 2, 
             fc = '1', ec = '0')
plt.xlim(-10, 60);

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             fc = 'springgreen', ec = 'darkgreen');

# %%
apt.head()
# Out:
#            아파트      시    구    동   지번  건축년도        거래일    전용면적   층   거래금액  ...  \
# 0  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-01-03  111.97   6  10.00  ...
# 1  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-02-21  108.95   7   9.60  ...
# 2  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2021-10-25  111.97   8  14.00  ...
# 3        세종로대우  서울특별시  종로구  내수동  167  1994 2020-01-06  109.91  11   8.80  ...
# 4        세종로대우  서울특별시  종로구  내수동  167  1994 2020-02-20   66.96  12   6.15  ...
#
#     금액구분         위도          경도 동수 세대수  임대수  용적률  건폐율  주차대수         건설사
# 0  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 1  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 2  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 3  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
# 4  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
#
# [5 rows x 24 columns]

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             hue = '금액구분', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             hue = '금액구분', ec = '0', palette = 'Set1');

# %% [raw]
# sns.choose_colorbrewer_palette('qualitative');

# %% [raw]
# sns.choose_colorbrewer_palette('sequential');

# %% [raw]
# sns.choose_colorbrewer_palette('diverging');

# %%
dir(plt.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  '_LUTSIZE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_norm_from_scale',
#  '_colormaps',
#  '_ensure_cmap',
#  '_gen_cmap_registry',
#  '_get_cmap',
#  'afmhot',
#  'afmhot_r',
#  'autumn',
#  'autumn_r',
#  'binary',
#  'binary_r',
#  'bone',
#  'bone_r',
#  'brg',
#  'brg_r',
#  'bwr',
#  'bwr_r',
#  'cbook',
#  'cividis',
#  'cividis_r',
#  'cmaps_listed',
#  'colors',
#  'cool',
#  'cool_r',
#  'coolwarm',
#  'coolwarm_r',
#  'copper',
#  'copper_r',
#  'cubehelix',
#  'cubehelix_r',
#  'datad',
#  'flag',
#  'flag_r',
#  'functools',
#  'get_cmap',
#  'gist_earth',
#  'gist_earth_r',
#  'gist_gray',
#  'gist_gray_r',
#  'gist_heat',
#  'gist_heat_r',
#  'gist_ncar',
#  'gist_ncar_r',
#  'gist_rainbow',
#  'gist_rainbow_r',
#  'gist_stern',
#  'gist_stern_r',
#  'gist_yarg',
#  'gist_yarg_r',
#  'gnuplot',
#  'gnuplot2',
#  'gnuplot2_r',
#  'gnuplot_r',
#  'gray',
#  'gray_r',
#  'hot',
#  'hot_r',
#  'hsv',
#  'hsv_r',
#  'inferno',
#  'inferno_r',
#  'jet',
#  'jet_r',
#  'ma',
#  'magma',
#  'magma_r',
#  'mpl',
#  'nipy_spectral',
#  'nipy_spectral_r',
#  'np',
#  'ocean',
#  'ocean_r',
#  'pink',
#  'pink_r',
#  'plasma',
#  'plasma_r',
#  'prism',
#  'prism_r',
#  'rainbow',
#  'rainbow_r',
#  'register_cmap',
#  'scale',
#  'seismic',
#  'seismic_r',
#  'spring',
#  'spring_r',
#  'summer',
#  'summer_r',
#  'tab10',
#  'tab10_r',
#  'tab20',
#  'tab20_r',
#  'tab20b',
#  'tab20b_r',
#  'tab20c',
#  'tab20c_r',
#  'terrain',
#  'terrain_r',
#  'turbo',
#  'turbo_r',
#  'twilight',
#  'twilight_r',
#  'twilight_shifted',
#  'twilight_shifted_r',
#  'unregister_cmap',
#  'viridis',
#  'viridis_r',
#  'winter',
#  'winter_r']

# %%
sns.color_palette(palette = 'twilight')
# Out:
# [(0.5383401557517628, 0.677970811290954, 0.7711273443905772),
#  (0.37324816143326384, 0.38140848555753937, 0.7059820097480604),
#  (0.28669151388283165, 0.08242987384848069, 0.39331182532243375),
#  (0.3153587000920581, 0.07942099731524319, 0.2681190407694196),
#  (0.6456734938264543, 0.2615520316161528, 0.31248673753935263),
#  (0.7904577684772788, 0.5982813427706246, 0.48622257801969754)]

# %%
sns.color_palette(palette = 'Spectral', n_colors = 10)
# Out:
# [(0.8141484044598232, 0.2196847366397539, 0.3048058439061899),
#  (0.9330257593233372, 0.3913110342176086, 0.27197231833910035),
#  (0.9817762399077278, 0.6073817762399076, 0.3457900807381776),
#  (0.9946943483275663, 0.8092272202998846, 0.48696655132641287),
#  (0.9982314494425221, 0.9451749327181853, 0.6570549788542868),
#  (0.9557862360630527, 0.9823144944252211, 0.6800461361014996),
#  (0.8202998846597465, 0.9275663206459055, 0.6126874279123413),
#  (0.5910034602076126, 0.835524798154556, 0.6442906574394464),
#  (0.3600153787004998, 0.7161860822760476, 0.6655132641291811),
#  (0.21299500192233756, 0.5114186851211072, 0.730795847750865)]

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.set_palette(palette = 'Set1')

# %%
sns.color_palette()
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  (1.0, 0.4980392156862745, 0.0),
#  (1.0, 1.0, 0.2),
#  (0.6509803921568628, 0.33725490196078434, 0.1568627450980392),
#  (0.9686274509803922, 0.5058823529411764, 0.7490196078431373),
#  (0.6, 0.6, 0.6)]

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             hue = '금액구분', ec = '0')
plt.yscale('log');

# %%
apt.head()
# Out:
#            아파트      시    구    동   지번  건축년도        거래일    전용면적   층   거래금액  ...  \
# 0  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-01-03  111.97   6  10.00  ...
# 1  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2020-02-21  108.95   7   9.60  ...
# 2  신동아블루아광화문의꿈  서울특별시  종로구  필운동  254  2007 2021-10-25  111.97   8  14.00  ...
# 3        세종로대우  서울특별시  종로구  내수동  167  1994 2020-01-06  109.91  11   8.80  ...
# 4        세종로대우  서울특별시  종로구  내수동  167  1994 2020-02-20   66.96  12   6.15  ...
#
#     금액구분         위도          경도 동수 세대수  임대수  용적률  건폐율  주차대수         건설사
# 0  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 1  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 2  5천 미만  37.575816  126.969968  1  28    0  515   59    39  (주)신동아종합건설
# 3  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
# 4  5천 미만  37.572764  126.973305  1  60    0  499   38   167        대우건설
#
# [5 rows x 24 columns]

# %%
myPal = ['silver', 'red']

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             hue = '금액구분', ec = '0', palette = myPal,
             hue_order = ['5천 미만', '5천 이상']);

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             hue = '금액구분', ec = '0', palette = myPal,
             hue_order = ['5천 미만', '5천 이상'])
plt.title(label = '거래금액의 분포')
plt.xlabel(xlabel = '매매가격')
plt.ylabel(ylabel = '매매건수');

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             fc = '1', ec = '0');

# %%
sns.histplot(data = apt, x = '거래금액', 
             binrange = (0, 60), binwidth = 2, 
             fc = '1', ec = '0.8', stat = 'density')
sns.kdeplot(data = apt, x = '거래금액', color = 'red', lw = 0.5)
plt.xlim(-10, 60);

# %%
sub = apt[apt['구'].str.contains(pat = '강[남동]')]

# %%
pd.pivot_table(data = sub, values = '거래금액', index = '구', 
               aggfunc = [np.size, np.mean, np.std])
# Out:
#      size       mean        std
#      거래금액       거래금액       거래금액
# 구
# 강남구  6473  19.359067  11.450677
# 강동구  6633   8.726773   4.322631

# %%
sns.histplot(data = sub, x = '거래금액', hue = '구', 
             binrange = (0, 150), binwidth = 2, 
             palette = myPal, hue_order = ['강동구', '강남구']);

# %%
sns.kdeplot(data = sub, x = '거래금액', hue = '구', fill = True, 
            palette = myPal, hue_order = ['강동구', '강남구']);

# %%
sns.boxplot(data = apt, y = '거래금액', color = 'orange', linewidth = 0.5);

# %%
outProps = {
    'marker': 'o', 
    'markersize': 3, 
    'markerfacecolor': 'pink', 
    'markeredgecolor': 'red', 
    'markeredgewidth': 0.2
}

# %%
sns.boxplot(data = apt, y = '거래금액', color = 'orange', linewidth = 0.5, 
            flierprops = outProps);

# %%
grp = apt.groupby(by = ['구'])['거래금액'].median().sort_values()
grp
# Out:
# 구
# 도봉구      4.7500
# 금천구      5.1500
# 노원구      5.4500
# 중랑구      5.5000
# 구로구      5.9000
# 강북구      6.0000
# 은평구      6.5500
# 관악구      6.7000
# 강서구      6.7975
# 성북구      7.3000
# 동대문구     7.3500
# 서대문구     7.8000
# 종로구      7.9500
# 양천구      8.3600
# 영등포구     8.6000
# 강동구      8.7000
# 중구       9.2100
# 동작구     10.0000
# 마포구     10.4800
# 광진구     11.2500
# 성동구     11.8000
# 송파구     13.2000
# 용산구     14.6000
# 서초구     17.8000
# 강남구     18.2000
# Name: 거래금액, dtype: float64

# %%
sns.boxplot(data = apt, x = '구', y = '거래금액', 
            linewidth = 0.5, flierprops = outProps, order = grp.index)
plt.xticks(rotation = 90);

# %% [raw]
# apt['구'].value_counts()

# %%
grp = apt.groupby(by = ['구'])['거래금액'].count().sort_values(ascending = False)
grp
# Out:
# 구
# 노원구     12897
# 강서구      9122
# 구로구      7401
# 송파구      7333
# 성북구      7204
# 강동구      6633
# 강남구      6473
# 도봉구      6031
# 영등포구     5896
# 서초구      5729
# 양천구      5620
# 은평구      5608
# 동대문구     5379
# 마포구      4768
# 성동구      4760
# 중랑구      4707
# 동작구      4688
# 관악구      4512
# 서대문구     4258
# 강북구      3264
# 금천구      2704
# 용산구      2505
# 광진구      2245
# 중구       1756
# 종로구      1320
# Name: 거래금액, dtype: int64

# %%
sns.countplot(data = apt, x = '구', order = grp.index)
plt.xticks(rotation = 90)
plt.ylim(0, 14000)

for i, v in enumerate(grp):
    plt.text(x = i, y = v + 100, s = f'{v:,}', 
             ha = 'center', va = 'bottom', fontsize = 8)

# %%
myPal = np.tile('silver', 25)
myPal[0] = 'red'

# %%
plt.figure(figsize = (8, 8))
sns.countplot(data = apt, y = '구', order = grp.index, palette = myPal)
plt.xlim(0, 14000)

for i, v in enumerate(grp):
    plt.text(y = i, x = v + 100, s = f'{v:,}', 
             ha = 'left', va = 'center', fontsize = 8)

# %%
sub2 = apt[apt['구'].isin(values = ['강남구', '서초구', '용산구'])]

# %%
grp = sub2['구'].value_counts()
grp
# Out:
# 강남구    6473
# 서초구    5729
# 용산구    2505
# Name: 구, dtype: int64

# %%
plt.pie(x = grp.values, explode = [0, 0, 0.2], 
        labels = grp.index, autopct = '%.1f%%', 
        colors = ['silver', 'silver', 'orange'], 
        startangle = 90, counterclock = False, 
        textprops = dict(c = '0', size = 10), 
        wedgeprops = dict(ec = '0', lw = 0.5));

# %%
grp = apt.groupby(by = ['구'])['거래금액'].mean().sort_values()
grp
# Out:
# 구
# 도봉구      5.049250
# 금천구      5.384921
# 중랑구      5.581186
# 노원구      5.752561
# 강북구      5.948995
# 구로구      6.051199
# 관악구      6.520717
# 은평구      6.612472
# 강서구      7.140650
# 성북구      7.232669
# 동대문구     7.251955
# 서대문구     8.069557
# 종로구      8.662705
# 강동구      8.726773
# 중구       9.116405
# 영등포구     9.224347
# 양천구      9.478181
# 동작구     10.399646
# 마포구     10.766300
# 광진구     11.176043
# 성동구     12.565477
# 송파구     14.018360
# 용산구     17.306284
# 서초구     18.524445
# 강남구     19.359067
# Name: 거래금액, dtype: float64

# %%
sns.barplot(data = apt, x = '구', y = '거래금액', order = grp.index, 
            estimator = np.mean, errorbar = None)
plt.ylim(0, 22.5)
plt.xticks(rotation = 90)

for i, v in enumerate(grp):
    plt.text(x = i, y = v + 0.2, s = f'{v:.1f}', 
             ha = 'center', va = 'bottom', fontsize = 8)

# %%
apt = apt.sort_values(by = ['거래월'])

# %%
sns.lineplot(data = apt, x = '거래월', y = '거래금액', c = 'red', 
             estimator = np.mean, errorbar = None);

# %%
sns.lineplot(data = apt, x = '거래월', y = '거래금액', c = 'red', 
             estimator = np.mean, errorbar = None, marker = 'o');

# %%
sns.lineplot(data = apt, x = '거래월', y = '거래금액', hue = '거래년도', 
             estimator = np.mean, errorbar = None, marker = 'o');

# %%
sns.lineplot(data = apt, x = '거래월', y = '거래금액', hue = '거래년도', 
             estimator = np.mean, errorbar = None, markers = True, 
             style = '거래년도')
plt.legend(loc = 'lower left');

# %%
sns.barplot(data = apt, x = '거래월', y = '거래금액', 
            estimator = np.mean)
sns.lineplot(data = apt, x = '거래월', y = '거래금액', 
            estimator = np.mean);

# %%
fig = plt.figure()
ax1 = fig.add_subplot()
sns.barplot(data = apt, x = '거래월', y = '거래금액', 
            estimator = np.size, errorbar = None, ax = ax1)
ax1.set_ylim(0, 30000)

ax2 = ax1.twinx()
sns.lineplot(data = apt, x = '거래월', y = '평당금액', 
            estimator = np.mean, errorbar = None, ax = ax2);

# %%
sns.scatterplot(data = apt, x = '전용면적', y = '거래금액', 
                fc = '0.3', ec = '0.8', s = 15, alpha = 0.2);

# %%
apt = apt.sort_values(by = ['세대수'])

# %%
sns.scatterplot(data = apt, x = '전용면적', y = '거래금액', 
                hue = '세대수', palette = 'RdYlGn', 
                ec = '0.8', s = 15, alpha = 0.2);

# %%
gng = apt[apt['구'].eq('강남구')]

# %%
sns.scatterplot(data = gng, x = '전용면적', y = '거래금액', 
                hue = '세대수', palette = 'RdYlGn', 
                ec = '0.8', s = 15, alpha = 0.2);

# %%
sns.regplot(data = gng, x = '전용면적', y = '거래금액', ci = None,
            scatter_kws = dict(fc = '0.3', ec = '0.8', s = 15, alpha = 0.2), 
            line_kws = dict(color = 'red', lw = 1.5))
plt.axvline(x = gng['전용면적'].mean(), color = 'red', lw = 0.5, ls = '--')
plt.axhline(y = gng['거래금액'].mean(), color = 'red', lw = 0.5, ls = '--');

# %%
sns.pairplot(data = gng, 
             x_vars = ['전용면적', '층', '세대수'], 
             y_vars = '거래금액', 
             kind = 'reg', 
             plot_kws = dict(
                scatter_kws = dict(fc = '0.3', ec = '0.8', s = 15, alpha = 0.2), 
                line_kws = dict(color = 'red', lw = 1.5)
             ))
